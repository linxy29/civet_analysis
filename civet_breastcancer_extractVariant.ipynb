# %%
import pandas as pd
import numpy as np
from utilities import *

# %% [markdown]
# ### Read data

# %%
## variant data
variant_folder = "/home/linxy29/data/CIVET/visium_breastcancer_10x/spaceranger_cellSNP0/"
breastcancer_mquad, breastcancer_barcode = load_cellsnp(variant_folder)
print("The dimension of the AD data is: ", breastcancer_mquad.ad.shape)
print("The dimension of the DP data is: ", breastcancer_mquad.dp.shape)
print("The number of mtSNPs is: ", len(breastcancer_mquad.variants))
# Out:
# Loaded VCF file: /home/linxy29/data/CIVET/visium_breastcancer_10x/spaceranger_cellSNP0/cellSNP.cells.vcf.gz
# 610 variants detected
# variant names detected
# The dimension of the AD data is:  (610, 4169)
# The dimension of the DP data is:  (610, 4169)
# The number of mtSNPs is:  610

# %%
## civet results
civet_res_folder = "/home/linxy29/data/CIVET/visium_breastcancer_10x/civet/q05_cell_abundance_res.csv"
civet_res = pd.read_csv(civet_res_folder)
civet_res = civet_res.dropna(axis=1, how='all')
civet_res
# Out:
#       variant  LR_vals.q05cell_abundance_w_sf_Cancer_Basal_SC  \
# 0     3308T>A                                             NaN
# 1     3309A>C                                             NaN
# 2     3310C>A                                             NaN
# 3     3311C>A                                        1.116060
# 4     3312C>A                                        0.031209
# ..        ...                                             ...
# 605  15758A>C                                       -0.072572
# 606  15759T>G                                        2.067343
# 607  15760C>A                                        0.020436
# 608  15761G>N                                       -0.025495
# 609  15762G>A                                             NaN
#
#      LR_vals.q05cell_abundance_w_sf_Cancer_Cycling  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                         7.164926
# 4                                         1.459276
# ..                                             ...
# 605                                      -0.327518
# 606                                       3.759955
# 607                                       0.300016
# 608                                       0.694657
# 609                                            NaN
#
#      LR_vals.q05cell_abundance_w_sf_Cancer_Her2_SC  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                         5.658235
# 4                                         1.178371
# ..                                             ...
# 605                                       0.587927
# 606                                      -0.026353
# 607                                       1.803673
# 608                                       0.365293
# 609                                            NaN
#
#      LR_vals.q05cell_abundance_w_sf_Cancer_LumA_SC  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                        -0.258697
# 4                                         3.136109
# ..                                             ...
# 605                                       0.697046
# 606                                       7.994066
# 607                                      -5.086837
# 608                                       0.255084
# 609                                            NaN
#
#      LR_vals.q05cell_abundance_w_sf_Cancer_LumB_SC  LR_vals.sum_cancer  \
# 0                                              NaN                 NaN
# 1                                              NaN                 NaN
# 2                                              NaN                 NaN
# 3                                         0.296724            0.180680
# 4                                         2.081446            2.306359
# ..                                             ...                 ...
# 605                                       0.953499            1.340740
# 606                                       6.462778            6.368065
# 607                                       0.508392            0.674060
# 608                                       0.179458            0.257735
# 609                                            NaN                 NaN
#
#      LRT_pvals.q05cell_abundance_w_sf_Cancer_Basal_SC  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                            0.290768
# 4                                            0.859775
# ..                                                ...
# 605                                          1.000000
# 606                                          0.150483
# 607                                          0.886325
# 608                                          1.000000
# 609                                               NaN
#
#      LRT_pvals.q05cell_abundance_w_sf_Cancer_Cycling  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                           0.007434
# 4                                           0.227045
# ..                                               ...
# 605                                         1.000000
# 606                                         0.052494
# 607                                         0.583873
# 608                                         0.404585
# 609                                              NaN
#
#      LRT_pvals.q05cell_abundance_w_sf_Cancer_Her2_SC  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3                                           0.017374  ...
# 4                                           0.277688  ...
# ..                                               ...  ...
# 605                                         0.443222  ...
# 606                                         1.000000  ...
# 607                                         0.179269  ...
# 608                                         0.545581  ...
# 609                                              NaN  ...
#
#      Wald_pvals.q05cell_abundance_w_sf_Cancer_Her2_SC  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                            0.006226
# 4                                            0.451498
# ..                                                ...
# 605                                          0.276710
# 606                                          0.985219
# 607                                          0.145856
# 608                                          0.592320
# 609                                               NaN
#
#      Wald_pvals.q05cell_abundance_w_sf_Cancer_LumA_SC  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                            0.255466
# 4                                            0.075086
# ..                                                ...
# 605                                          0.385119
# 606                                          0.006933
# 607                                          0.001777
# 608                                          0.616686
# 609                                               NaN
#
#      Wald_pvals.q05cell_abundance_w_sf_Cancer_LumB_SC  Wald_pvals.sum_cancer  \
# 0                                                 NaN                    NaN
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3                                            0.573937               0.666948
# 4                                            0.152995               0.090866
# ..                                                ...                    ...
# 605                                          0.603423               0.231444
# 606                                          0.017945               0.010915
# 607                                          0.455706               0.414038
# 608                                          0.739058               0.614144
# 609                                               NaN                    NaN
#
#      LRT_fdr.q05cell_abundance_w_sf_Cancer_Basal_SC  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                          0.992034
# 4                                          1.000000
# ..                                              ...
# 605                                        1.000000
# 606                                        0.920740
# 607                                        1.000000
# 608                                        1.000000
# 609                                             NaN
#
#      LRT_fdr.q05cell_abundance_w_sf_Cancer_Cycling  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                         0.286343
# 4                                         0.970115
# ..                                             ...
# 605                                       1.000000
# 606                                       0.613234
# 607                                       1.000000
# 608                                       1.000000
# 609                                            NaN
#
#      LRT_fdr.q05cell_abundance_w_sf_Cancer_Her2_SC  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                         0.407355
# 4                                         0.986711
# ..                                             ...
# 605                                       1.000000
# 606                                       1.000000
# 607                                       0.939326
# 608                                       1.000000
# 609                                            NaN
#
#      LRT_fdr.q05cell_abundance_w_sf_Cancer_LumA_SC  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                         1.000000
# 4                                         0.740237
# ..                                             ...
# 605                                       1.000000
# 606                                       0.224068
# 607                                       1.000000
# 608                                       1.000000
# 609                                            NaN
#
#      LRT_fdr.q05cell_abundance_w_sf_Cancer_LumB_SC  LRT_fdr.sum_cancer
# 0                                              NaN                 NaN
# 1                                              NaN                 NaN
# 2                                              NaN                 NaN
# 3                                         1.000000            1.000000
# 4                                         0.920740            0.903023
# ..                                             ...                 ...
# 605                                       0.997772            0.978733
# 606                                       0.351792            0.351792
# 607                                       1.000000            1.000000
# 608                                       1.000000            1.000000
# 609                                            NaN                 NaN
#
# [610 rows x 25 columns]

# %%
# Filter out columns containing '.q05cell_abundance_w_sf_'
filtered_columns = [col for col in civet_res.columns if '.q05cell_abundance_w_sf_' in col]

# Extract statistics names and cell types
stats_names = set()
cell_types = set()

for col in filtered_columns:
    stat_name, cell_info = col.split('.q05cell_abundance_w_sf_')
    cell_types.add(cell_info)

# Convert to sorted lists for better readability
unique_stats_names = ['LRT_fdr', 'LRT_pvals', 'Wald_pvals']
unique_cell_types = sorted(list(cell_types))
print(unique_cell_types)
# Out:
# ['Cancer_Basal_SC', 'Cancer_Cycling', 'Cancer_Her2_SC', 'Cancer_LumA_SC', 'Cancer_LumB_SC']

# %%
for stat_name in unique_stats_names:
    for cell_type in unique_cell_types:
        col_name = f'{stat_name}.q05cell_abundance_w_sf_{cell_type}'
        # Select the variants with LRT_fdr > 0.05
        selected_variants = civet_res[civet_res[col_name] > 0.05]['variant']
        print(f"Number of variants with {stat_name} > 0.05 for {cell_type}: {len(selected_variants)}")
        subset_mquad, subset_barcode = select_mquad(breastcancer_mquad, breastcancer_barcode, include_variant_names=selected_variants) 
        write_mquad(breastcancer_mquad, breastcancer_barcode, f'/home/linxy29/data/CIVET/visium_breastcancer_10x/civet/civet_{stat_name}_{cell_type}005')
        selected_variants = civet_res[civet_res[col_name] > 0.1]['variant']
        print(f"Number of variants with {stat_name} > 0.1 for {cell_type}: {len(selected_variants)}")
        subset_mquad, subset_barcode = select_mquad(breastcancer_mquad, breastcancer_barcode, include_variant_names=selected_variants)
        write_mquad(breastcancer_mquad, breastcancer_barcode, f'/home/linxy29/data/CIVET/visium_breastcancer_10x/civet/civet_{stat_name}_{cell_type}01')
# Out:
# Number of variants with LRT_fdr > 0.05 for Cancer_Basal_SC: 546
# Number of variants with LRT_fdr > 0.1 for Cancer_Basal_SC: 546
# Number of variants with LRT_fdr > 0.05 for Cancer_Cycling: 546
# Number of variants with LRT_fdr > 0.1 for Cancer_Cycling: 544
# Number of variants with LRT_fdr > 0.05 for Cancer_Her2_SC: 546
# Number of variants with LRT_fdr > 0.1 for Cancer_Her2_SC: 546
# Number of variants with LRT_fdr > 0.05 for Cancer_LumA_SC: 545
# Number of variants with LRT_fdr > 0.1 for Cancer_LumA_SC: 544
# Number of variants with LRT_fdr > 0.05 for Cancer_LumB_SC: 546
# Number of variants with LRT_fdr > 0.1 for Cancer_LumB_SC: 545
# Number of variants with LRT_pvals > 0.05 for Cancer_Basal_SC: 506
# Number of variants with LRT_pvals > 0.1 for Cancer_Basal_SC: 478
# Number of variants with LRT_pvals > 0.05 for Cancer_Cycling: 513
# Number of variants with LRT_pvals > 0.1 for Cancer_Cycling: 494
# Number of variants with LRT_pvals > 0.05 for Cancer_Her2_SC: 503
# Number of variants with LRT_pvals > 0.1 for Cancer_Her2_SC: 486
# Number of variants with LRT_pvals > 0.05 for Cancer_LumA_SC: 503
# Number of variants with LRT_pvals > 0.1 for Cancer_LumA_SC: 484
# Number of variants with LRT_pvals > 0.05 for Cancer_LumB_SC: 505
# Number of variants with LRT_pvals > 0.1 for Cancer_LumB_SC: 483
# Number of variants with Wald_pvals > 0.05 for Cancer_Basal_SC: 512
# Number of variants with Wald_pvals > 0.1 for Cancer_Basal_SC: 480
# Number of variants with Wald_pvals > 0.05 for Cancer_Cycling: 490
# Number of variants with Wald_pvals > 0.1 for Cancer_Cycling: 463
# Number of variants with Wald_pvals > 0.05 for Cancer_Her2_SC: 510
# Number of variants with Wald_pvals > 0.1 for Cancer_Her2_SC: 485
# Number of variants with Wald_pvals > 0.05 for Cancer_LumA_SC: 502
# Number of variants with Wald_pvals > 0.1 for Cancer_LumA_SC: 478
# Number of variants with Wald_pvals > 0.05 for Cancer_LumB_SC: 507
# Number of variants with Wald_pvals > 0.1 for Cancer_LumB_SC: 481
