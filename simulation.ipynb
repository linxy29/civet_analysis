# %% [markdown]
# **Simulation Design for Mitochondrial Lineage Tracing and Single-Cell Transcriptomic Data**
#
# ### **1. Overview**
#
# The simulation consists of four main components:
#
# 1. **Stem Cell Growth Simulation**: Modeling the proliferation of stem cells using the Gillespie algorithm.
# 2. **Mitochondrial Genome Proliferation**: Simulating mtDNA replication, mutation accumulation, and segregation during cell division.
# 3. **Cell Differentiation Simulation**: Modeling asymmetric division of progenitor cells and differentiation into various cell types.
# 4. **Single-Cell Transcriptomic Data Simulation**: Generating gene expression data using latent variables and sampling from a Zero-Inflated Negative Binomial (ZINB) distribution.
#
# ---
#
# ### **2. Simulation of Stem Cell Growth**
#
# **2.1. Model Description**
#
# We simulate stem cell growth by conceptualizing cell division as a continuous-time Markov process. The division rate \( p(t) \) of a stem cell at time \( t \) is defined as:
#
# $$
# p(t) = r \left(1 - \frac{1}{1 + e^{-\kappa (t - t_0)}}\right),
# $$
#
# where:
#
# - \( r \) is the maximum division rate.
# - \( \kappa \) controls the rate at which the growth accelerates.
# - \( t_0 \) represents the inflection point in time when the growth rate changes significantly.
#
# **2.2. Simulation Implementation**
#
# We use the Gillespie stochastic simulation algorithm to model the timing of cell divisions. Starting from a single stem cell, we simulate cell divisions until the desired population size is reached.
#
# ---
#
# ### **3. Simulation of Mitochondrial Genome Proliferation**
#
# **3.1. Initial mtDNA Population**
#
# Each stem cell contains an initial population of mtDNA molecules. We simulate the replication and death of mtDNA molecules within the cell until a target copy number (e.g., 500 copies) is reached.
#
# **3.2. mtDNA Replication and Mutation**
#
# During cell division, mtDNA molecules replicate, and mutations can occur. The key aspects of the mtDNA dynamics include:
#
# - **Replication**: Each mtDNA molecule replicates once.
# - **Mutation Accumulation**: Mutations occur during replication, with the number of mutations following a Poisson distribution.
# - **Segregation**: mtDNA molecules are randomly segregated into daughter cells during cell division.
#
# **3.3. Mutation Rate Estimation**
#
# Assuming a per-mitosis mutation rate for mtDNA that is higher than nuclear DNA, we estimate the expected number of mtDNA mutations per cell division:
#
# $$
# \text{Expected mutations per division} = \mu \times \text{mtDNA copies},
# $$
#
# where \( \mu \) is the mutation rate per mtDNA molecule per division.
#
# ---
#
# ### **4. Simulation of Cell Differentiation**
#
# **4.1. Differentiation Models**
#
# After stem cell growth, cells differentiate according to specified models:
#
# - **Linear Differentiation**: Stem cells differentiate into progenitor cells, which further differentiate into a single cell type.
# - **Bifurcated Differentiation**: Progenitor cells differentiate into multiple cell types.
#
# **4.2. Asymmetric Division of Progenitor Cells**
#
# Progenitor cells undergo asymmetric division:
#
# - One daughter cell remains a progenitor cell capable of self-renewal and further differentiation.
# - The other daughter cell differentiates into a specialized cell type and no longer divides.
#
# **4.3. Differentiation Probability**
#
# Cell differentiation is modeled as a continuous-time Markov process, with a differentiation probability \( q_{ij}(t) \) at time \( t \):
#
# $$
# q_{ij}(t) = 1 - p_i(t),
# $$
#
# where \( p_i(t) \) is the probability that a cell remains in its current state.
#
# ---
#
# ### **5. Simulation of Single-Cell Transcriptomic Data**
#
# **5.1. Gene Expression Model**
#
# We simulate gene expression for each cell, accounting for cell-type-specific and shared genes:
#
# - **Cell-Type-Specific Genes**: Comprise 40% of the simulated genes, following distinct expression programs in different cell types.
# - **Shared Genes**: The remaining genes, with consistent expression across cell types.
#
# **5.2. Two-Step Expression Simulation**
#
# 1. **Latent Expression Generation**:
#
#    For each gene, we generate a latent expression variable \( z_t \) for cell generation \( t \):
#
#    $$
#    z_t \sim \text{Normal}(\mu_t, \sigma^2),
#    $$
#
#    where \( \mu_t \) is the mean expression level dependent on the cell's generation and cell type.
#
# 2. **Sampling Expression Data**:
#
#    The observed gene expression \( x_t \) is sampled from a Zero-Inflated Negative Binomial distribution:
#
#    $$
#    x_t \sim \text{ZINB}(\lambda = e^{z_t}, \theta, \pi),
#    $$
#
#    where:
#
#    - \( \lambda \) is the mean expression level.
#    - \( \theta \) is the dispersion parameter.
#    - \( \pi \) is the zero-inflation probability.
#
# **5.3. Parameters**
#
# - **Base Expression Levels**: Randomly assigned for each gene.
# - **Expression Rates**: Define how gene expression changes with cell generation.
# - **Dispersion and Zero-Inflation Parameters**: Set to mimic realistic single-cell RNA-seq data.
#
# ---
#
# ### **6. Simulation of Sequencing Read Depth for Mitochondrial Mutations**
#
# **6.1. Motivation**
#
# In sequencing data, the total read depth (DP) represents the number of sequencing reads covering a particular genomic position, while the allele depth (AD) represents the number of reads supporting a specific allele (e.g., a mutation) at that position. Including DP and AD in our simulation allows us to model the stochastic nature of sequencing and the variability in detecting mitochondrial mutations.
#
# **6.2. Modeling Read Depth**
#
# For each mitochondrial mutation in each cell:
#
# - **Total Read Depth (DP)**: Simulated using a suitable distribution (e.g., Poisson or Negative Binomial) to reflect variability in sequencing coverage.
# - **Allele Read Depth (AD)**: Simulated based on the heteroplasmy level of the mutation and the total read depth.
#
# **6.3. Implementation Details**
#
# - **Per-Mutation DP Simulation**: We simulate the DP for each mutation site in each cell.
# - **AD Calculation**: Given the DP and the heteroplasmy level (proportion of mtDNA molecules carrying the mutation), we simulate the AD using a binomial distribution.
# - **Error Modeling**: We can include sequencing errors by introducing a base error rate, affecting the observed AD.
#
# ---
#
# ### **7. Python Code Implementation**
#
# Below is the complete Python code implementing the simulation design. Explanations are provided within the code comments.

# %%
import numpy as np
import pandas as pd
import random
from collections import deque

# Set random seed for reproducibility
np.random.seed(42)

# --- Simulation Parameters ---

# Stem cell growth parameters
r = 1.0        # Maximum division rate
kappa = 0.1    # Growth acceleration rate
t0 = 50        # Inflection point in time

# mtDNA parameters
mtDNA_initial_count = 500
mtDNA_mutation_rate_per_mitosis = 0.4   # Mutations per cell division

# Sequencing read depth parameters
mean_dp = 100     # Mean total read depth per mutation site
dp_dispersion = 0.2  # Dispersion parameter for total read depth (overdispersion)
base_error_rate = 0.001  # Sequencing error rate

# Cell differentiation parameters
kappa_diff = 0.1  # Differentiation rate parameter
t0_diff = 50      # Differentiation inflection time

# Gene expression parameters
num_genes = 4000
cell_type_specific_genes = int(num_genes * 0.4)
shared_genes = num_genes - cell_type_specific_genes
alpha = 0.1  # Dispersion parameter for Negative Binomial
zero_inflation_prob = 0.1  # Probability of zero-inflation in gene expression

# Simulation settings
total_cells = 1000  # Total number of stem cells to simulate
max_generations = 10  # Max generations for stem cell divisions

# --- Class Definitions ---

class mtDNA:
    def __init__(self, id, mutations=None):
        self.id = id
        self.mutations = set(mutations) if mutations else set()

class Cell:
    def __init__(self, id, parent_id, generation, time, mtDNA_list=None, cell_type='StemCell'):
        self.id = id
        self.parent_id = parent_id
        self.generation = generation
        self.time = time
        self.mtDNA_list = mtDNA_list if mtDNA_list else []
        self.cell_type = cell_type
        self.children = []
        self.mutation_profile = {}  # To store DP and AD for mutations

# --- Functions for mtDNA Dynamics ---

def introduce_mutations(mtDNA_list, mutation_rate):
    """Introduce mutations into mtDNA molecules."""
    for mt in mtDNA_list:
        num_mutations = np.random.poisson(mutation_rate)
        for _ in range(num_mutations):
            mutation = f"m{np.random.randint(16500)}"
            mt.mutations.add(mutation)
    return mtDNA_list

def replicate_and_segregate_mtDNA(mtDNA_list):
    """Replicate and segregate mtDNA during cell division."""
    # Replicate mtDNA
    replicated_mtDNA = []
    for mt in mtDNA_list:
        replicated_mtDNA.append(mt)
        replicated_mtDNA.append(mtDNA(mt.id, mt.mutations.copy()))
    # Introduce mutations
    mutation_rate = mtDNA_mutation_rate_per_mitosis / len(replicated_mtDNA)
    replicated_mtDNA = introduce_mutations(replicated_mtDNA, mutation_rate)
    # Segregate mtDNA to daughter cells
    total_mtDNA = len(replicated_mtDNA)
    segregation_counts = np.random.multinomial(total_mtDNA, [0.5, 0.5])
    indices = np.random.permutation(total_mtDNA)
    daughter1_indices = indices[:segregation_counts[0]]
    daughter2_indices = indices[segregation_counts[0]:]
    daughter1_mtDNA = [replicated_mtDNA[i] for i in daughter1_indices]
    daughter2_mtDNA = [replicated_mtDNA[i] for i in daughter2_indices]
    return [daughter1_mtDNA, daughter2_mtDNA]

# --- Functions for Cell Growth and Differentiation ---

def division_rate(t, r, kappa, t0):
    """Calculate cell division rate at time t."""
    return r * (1 - 1 / (1 + np.exp(-kappa * (t - t0))))

def differentiation_probability(t, kappa_diff, t0_diff):
    """Calculate cell differentiation probability at time t."""
    return 1 - (1 / (1 + np.exp(-kappa_diff * (t - t0_diff))))

def simulate_stem_cell_growth():
    """Simulate stem cell growth using the Gillespie algorithm."""
    cells = []
    cell_id_counter = 0
    time = 0.0
    cell_queue = deque()

    # Initialize the first cell
    mtDNA_population = [mtDNA(i) for i in range(mtDNA_initial_count)]
    initial_cell = Cell(cell_id_counter, None, 0, time, mtDNA_population.copy(), 'StemCell')
    cells.append(initial_cell)
    cell_queue.append(initial_cell)
    cell_id_counter += 1

    # Simulate stem cell divisions
    while len(cells) < total_cells:
        current_cell = cell_queue.popleft()
        # Calculate division time
        div_rate = division_rate(current_cell.time, r, kappa, t0)
        division_t = np.random.exponential(scale=1.0 / div_rate)
        time += division_t

        # Replicate and segregate mtDNA
        daughter_mtDNAs = replicate_and_segregate_mtDNA(current_cell.mtDNA_list)

        # Create daughter cells
        for i in range(2):
            new_cell = Cell(
                cell_id_counter,
                current_cell.id,
                current_cell.generation + 1,
                time,
                daughter_mtDNAs[i],
                'StemCell'
            )
            cells.append(new_cell)
            cell_queue.append(new_cell)
            current_cell.children.append(new_cell.id)
            cell_id_counter += 1
    return cells

def simulate_cell_differentiation(cells):
    """Simulate cell differentiation after stem cell growth."""
    differentiated_cells = []
    progenitor_cells = []
    for cell in cells:
        if cell.cell_type == 'StemCell':
            # Decide whether the stem cell differentiates into a progenitor cell
            diff_prob = differentiation_probability(cell.time, kappa_diff, t0_diff)
            if np.random.rand() < diff_prob:
                cell.cell_type = 'Progenitor'
                progenitor_cells.append(cell)
        elif cell.cell_type == 'Progenitor':
            # Progenitor cells divide asymmetrically
            daughter_cells = progenitor_asymmetric_division(cell)
            differentiated_cells.extend(daughter_cells)
    return cells + differentiated_cells

def progenitor_asymmetric_division(cell):
    """Simulate asymmetric division of progenitor cells."""
    # Replicate and segregate mtDNA
    daughter_mtDNAs = replicate_and_segregate_mtDNA(cell.mtDNA_list)

    # One daughter remains progenitor
    progenitor_daughter = Cell(
        cell.id * 2,
        cell.id,
        cell.generation + 1,
        cell.time + 1,
        daughter_mtDNAs[0],
        'Progenitor'
    )

    # The other daughter differentiates
    differentiated_daughter = Cell(
        cell.id * 2 + 1,
        cell.id,
        cell.generation + 1,
        cell.time + 1,
        daughter_mtDNAs[1],
        'DifferentiatedType1'  # Assuming linear differentiation
    )

    return [progenitor_daughter, differentiated_daughter]

# --- Functions for Sequencing Read Depth Simulation ---

def simulate_read_depth(cell, all_mutations):
    """Simulate DP and AD for mitochondrial mutations in a cell."""
    mutation_index = {mutation: idx for idx, mutation in enumerate(all_mutations)}
    num_mutations = len(all_mutations)
    mtDNA_count = len(cell.mtDNA_list)

    # Calculate heteroplasmy levels
    mutation_counts = {}
    for mt in cell.mtDNA_list:
        for mutation in mt.mutations:
            mutation_counts[mutation] = mutation_counts.get(mutation, 0) + 1

    heteroplasmy = {mutation: count / mtDNA_count for mutation, count in mutation_counts.items()}

    # Simulate total read depth (DP) for each mutation site
    dp_values = np.random.negative_binomial(
        n=1 / dp_dispersion,
        p=1 / (1 + mean_dp * dp_dispersion),
        size=num_mutations
    )

    dp_values = dp_values + mean_dp  # Adjusting to have mean around mean_dp

    # Simulate allele depth (AD) based on heteroplasmy and DP
    ad_values = []
    dp_list = []
    for idx, mutation in enumerate(all_mutations):
        dp = max(int(dp_values[idx]), 1)  # Ensure at least 1 read
        dp_list.append(dp)
        h = heteroplasmy.get(mutation, base_error_rate)  # Use error rate if mutation not present
        # Include sequencing errors
        effective_h = h * (1 - base_error_rate) + (1 - h) * base_error_rate
        ad = np.random.binomial(dp, effective_h)
        ad_values.append(ad)

    # Store DP and AD in cell's mutation_profile
    cell.mutation_profile = {
        mutation: {'DP': dp_list[idx], 'AD': ad_values[idx]}
        for idx, mutation in enumerate(all_mutations)
    }

# --- Functions for Gene Expression Simulation ---

def generate_gene_params():
    """Generate parameters for gene expression simulation."""
    gene_ids = [f'Gene_{i}' for i in range(num_genes)]
    specific_gene_ids = random.sample(gene_ids, cell_type_specific_genes)
    shared_gene_ids = list(set(gene_ids) - set(specific_gene_ids))

    gene_params = {}
    for gene_id in gene_ids:
        if gene_id in specific_gene_ids:
            gene_params[gene_id] = {
                'base_expression': np.random.uniform(1, 5),
                'expression_rate': np.random.uniform(0.1, 0.5),
                'sigma': 1.0
            }
        else:
            gene_params[gene_id] = {
                'base_expression': np.random.uniform(1, 5),
                'expression_rate': 0.0,
                'sigma': 1.0
            }
    return gene_params

def generate_latent_expression(cell, gene_params):
    """Generate latent expression values for a cell."""
    z_t = {}
    for gene_id, params in gene_params.items():
        loc = params['base_expression'] + params['expression_rate'] * cell.generation
        scale = params['sigma']
        z_t[gene_id] = np.random.normal(loc=loc, scale=scale)
    return z_t

def sample_expression(z_t, alpha, zero_inflation_prob):
    """Sample gene expression counts from a ZINB distribution."""
    x_t = {}
    for gene_id, z in z_t.items():
        mu = np.exp(z)
        r = 1 / alpha
        p = r / (r + mu)
        if np.random.rand() < zero_inflation_prob:
            x_t[gene_id] = 0
        else:
            x_t[gene_id] = np.random.negative_binomial(n=r, p=p)
    return x_t

def simulate_gene_expression_for_cells(cells, gene_params):
    """Simulate gene expression for a list of cells."""
    expression_data = {}
    for cell in cells:
        z_t = generate_latent_expression(cell, gene_params)
        x_t = sample_expression(z_t, alpha, zero_inflation_prob)
        expression_data[cell.id] = x_t
    expression_df = pd.DataFrame.from_dict(expression_data, orient='index')
    return expression_df

# --- Main Simulation Execution ---

# Step 1: Simulate stem cell growth
stem_cells = simulate_stem_cell_growth()

# Step 2: Simulate cell differentiation
all_cells = simulate_cell_differentiation(stem_cells)

# Step 3: Collect all unique mutations across cells
all_mutations = set()
for cell in all_cells:
    for mt in cell.mtDNA_list:
        all_mutations.update(mt.mutations)
all_mutations = sorted(all_mutations)

# Step 4: Simulate sequencing read depth (DP and AD) for mitochondrial mutations
for cell in all_cells:
    simulate_read_depth(cell, all_mutations)

# Step 5: Generate gene expression parameters
gene_params = generate_gene_params()

# Step 6: Simulate gene expression
expression_df = simulate_gene_expression_for_cells(all_cells, gene_params)

# --- Data Output and Visualization ---

# Example: Display DP and AD for the first 5 cells
print("Mitochondrial Mutation Profiles (first 5 cells):")
for cell in all_cells[:5]:
    print(f"Cell ID: {cell.id}, Mutation Profile:")
    for mutation, counts in cell.mutation_profile.items():
        print(f"  Mutation: {mutation}, DP: {counts['DP']}, AD: {counts['AD']}")
    print()

# Example: Display gene expression data for the first 5 cells
print("Simulated Gene Expression Data (first 5 cells):")
print(expression_df.head())
# Out:
# /tmp/ipykernel_30101/2487653891.py:118: RuntimeWarning: divide by zero encountered in scalar divide
#   division_t = np.random.exponential(scale=1.0 / div_rate)
# Mitochondrial Mutation Profiles (first 5 cells):
# Cell ID: 0, Mutation Profile:
#   Mutation: m10069, DP: 175, AD: 0
#   Mutation: m10086, DP: 203, AD: 2
#   Mutation: m10131, DP: 235, AD: 0
#   Mutation: m10182, DP: 204, AD: 0
#   Mutation: m10212, DP: 153, AD: 0
#   Mutation: m10220, DP: 195, AD: 1
#   Mutation: m10289, DP: 165, AD: 1
#   Mutation: m10303, DP: 180, AD: 0
#   Mutation: m10402, DP: 203, AD: 0
#   Mutation: m10588, DP: 164, AD: 0
#   Mutation: m10637, DP: 134, AD: 1
#   Mutation: m10648, DP: 128, AD: 0
#   Mutation: m11060, DP: 272, AD: 1
#   Mutation: m11066, DP: 229, AD: 0
#   Mutation: m11158, DP: 221, AD: 0
#   Mutation: m11180, DP: 253, AD: 1
#   Mutation: m11331, DP: 161, AD: 0
#   Mutation: m11594, DP: 279, AD: 0
#   Mutation: m11800, DP: 123, AD: 0
#   Mutation: m1184, DP: 167, AD: 0
#   Mutation: m12055, DP: 201, AD: 0
#   Mutation: m12156, DP: 220, AD: 0
#   Mutation: m12193, DP: 244, AD: 1
#   Mutation: m12248, DP: 182, AD: 0
#   Mutation: m12254, DP: 188, AD: 0
#   Mutation: m12458, DP: 156, AD: 0
#   Mutation: m12474, DP: 194, AD: 1
#   Mutation: m12494, DP: 180, AD: 0
#   Mutation: m12495, DP: 137, AD: 0
#   Mutation: m12536, DP: 207, AD: 0
#   Mutation: m12689, DP: 174, AD: 0
#   Mutation: m12783, DP: 181, AD: 0
#   Mutation: m12834, DP: 265, AD: 0
#   Mutation: m12842, DP: 178, AD: 2
#   Mutation: m12909, DP: 261, AD: 1
#   Mutation: m12920, DP: 243, AD: 0
#   Mutation: m13011, DP: 208, AD: 0
#   Mutation: m13144, DP: 205, AD: 1
#   Mutation: m13286, DP: 169, AD: 0
#   Mutation: m13360, DP: 199, AD: 0
#   Mutation: m134, DP: 169, AD: 0
#   Mutation: m13408, DP: 208, AD: 0
#   Mutation: m13633, DP: 138, AD: 0
#   Mutation: m13785, DP: 165, AD: 0
#   Mutation: m14013, DP: 234, AD: 0
#   Mutation: m14016, DP: 251, AD: 0
#   Mutation: m14043, DP: 185, AD: 2
#   Mutation: m14049, DP: 291, AD: 1
#   Mutation: m14096, DP: 236, AD: 1
#   Mutation: m14161, DP: 221, AD: 0
#   Mutation: m14240, DP: 220, AD: 0
#   Mutation: m14314, DP: 198, AD: 0
#   Mutation: m14367, DP: 229, AD: 0
#   Mutation: m14403, DP: 190, AD: 0
#   Mutation: m14493, DP: 223, AD: 0
#   Mutation: m14578, DP: 231, AD: 0
#   Mutation: m14887, DP: 209, AD: 0
#   Mutation: m14940, DP: 132, AD: 0
#   Mutation: m15074, DP: 173, AD: 0
#   Mutation: m15183, DP: 295, AD: 0
#   Mutation: m1524, DP: 131, AD: 0
#   Mutation: m15256, DP: 225, AD: 0
#   Mutation: m15563, DP: 174, AD: 0
#   Mutation: m15621, DP: 153, AD: 0
#   Mutation: m15799, DP: 356, AD: 0
#   Mutation: m15940, DP: 182, AD: 0
#   Mutation: m16000, DP: 224, AD: 0
#   Mutation: m16108, DP: 155, AD: 1
#   Mutation: m1613, DP: 190, AD: 2
#   Mutation: m16165, DP: 243, AD: 4
#   Mutation: m16233, DP: 229, AD: 0
#   Mutation: m16359, DP: 159, AD: 0
#   Mutation: m16497, DP: 199, AD: 0
#   Mutation: m1751, DP: 223, AD: 0
#   Mutation: m1842, DP: 160, AD: 0
#   Mutation: m1980, DP: 248, AD: 1
#   Mutation: m2025, DP: 158, AD: 1
#   Mutation: m2056, DP: 314, AD: 0
#   Mutation: m2114, DP: 229, AD: 0
#   Mutation: m2375, DP: 167, AD: 0
#   Mutation: m2546, DP: 205, AD: 0
#   Mutation: m3094, DP: 179, AD: 0
#   Mutation: m3219, DP: 253, AD: 1
#   Mutation: m3321, DP: 129, AD: 1
#   Mutation: m3363, DP: 197, AD: 0
#   Mutation: m3364, DP: 291, AD: 0
#   Mutation: m3454, DP: 174, AD: 1
#   Mutation: m3482, DP: 217, AD: 0
#   Mutation: m349, DP: 142, AD: 0
#   Mutation: m3543, DP: 159, AD: 0
#   Mutation: m3636, DP: 177, AD: 0
#   Mutation: m3767, DP: 191, AD: 0
#   Mutation: m3796, DP: 169, AD: 0
#   Mutation: m3916, DP: 168, AD: 0
#   Mutation: m4200, DP: 253, AD: 2
#   Mutation: m4286, DP: 146, AD: 0
#   Mutation: m4351, DP: 204, AD: 0
#   Mutation: m4369, DP: 284, AD: 1
#   Mutation: m438, DP: 193, AD: 0
#   Mutation: m4439, DP: 248, AD: 0
#   Mutation: m4507, DP: 190, AD: 1
#   Mutation: m454, DP: 200, AD: 0
#   Mutation: m4784, DP: 231, AD: 1
#   Mutation: m4804, DP: 200, AD: 0
#   Mutation: m4812, DP: 159, AD: 0
#   Mutation: m4848, DP: 211, AD: 0
#   Mutation: m4996, DP: 194, AD: 0
#   Mutation: m5054, DP: 260, AD: 1
#   Mutation: m5061, DP: 187, AD: 0
#   Mutation: m5145, DP: 249, AD: 1
#   Mutation: m5190, DP: 182, AD: 0
#   Mutation: m520, DP: 179, AD: 0
#   Mutation: m5221, DP: 133, AD: 1
#   Mutation: m5228, DP: 186, AD: 1
#   Mutation: m5279, DP: 199, AD: 0
#   Mutation: m5323, DP: 226, AD: 1
#   Mutation: m5382, DP: 138, AD: 0
#   Mutation: m5383, DP: 312, AD: 3
#   Mutation: m5384, DP: 160, AD: 0
#   Mutation: m5435, DP: 284, AD: 2
#   Mutation: m5528, DP: 157, AD: 0
#   Mutation: m5529, DP: 198, AD: 0
#   Mutation: m5644, DP: 194, AD: 0
#   Mutation: m5663, DP: 174, AD: 0
#   Mutation: m5695, DP: 191, AD: 0
#   Mutation: m5764, DP: 185, AD: 0
#   Mutation: m5816, DP: 155, AD: 1
#   Mutation: m5851, DP: 142, AD: 1
#   Mutation: m5878, DP: 138, AD: 0
#   Mutation: m5881, DP: 204, AD: 1
#   Mutation: m5956, DP: 200, AD: 1
#   Mutation: m6069, DP: 178, AD: 1
#   Mutation: m6339, DP: 172, AD: 0
#   Mutation: m6393, DP: 210, AD: 1
#   Mutation: m6430, DP: 213, AD: 0
#   Mutation: m644, DP: 152, AD: 1
#   Mutation: m6576, DP: 180, AD: 0
#   Mutation: m6636, DP: 134, AD: 0
#   Mutation: m6638, DP: 187, AD: 1
#   Mutation: m6720, DP: 290, AD: 1
#   Mutation: m681, DP: 142, AD: 0
#   Mutation: m713, DP: 173, AD: 1
#   Mutation: m7132, DP: 122, AD: 0
#   Mutation: m7183, DP: 175, AD: 1
#   Mutation: m7193, DP: 216, AD: 0
#   Mutation: m7209, DP: 203, AD: 0
#   Mutation: m7228, DP: 271, AD: 0
#   Mutation: m7312, DP: 260, AD: 0
#   Mutation: m7318, DP: 146, AD: 0
#   Mutation: m7344, DP: 131, AD: 0
#   Mutation: m7392, DP: 163, AD: 0
#   Mutation: m7412, DP: 237, AD: 0
#   Mutation: m7435, DP: 188, AD: 0
#   Mutation: m7568, DP: 222, AD: 0
#   Mutation: m7582, DP: 207, AD: 0
#   Mutation: m7613, DP: 187, AD: 0
#   Mutation: m7662, DP: 187, AD: 0
#   Mutation: m7761, DP: 219, AD: 1
#   Mutation: m7827, DP: 168, AD: 1
#   Mutation: m7938, DP: 243, AD: 0
#   Mutation: m8308, DP: 160, AD: 0
#   Mutation: m8420, DP: 126, AD: 1
#   Mutation: m8424, DP: 233, AD: 1
#   Mutation: m8474, DP: 309, AD: 0
#   Mutation: m8534, DP: 214, AD: 1
#   Mutation: m8764, DP: 201, AD: 0
#   Mutation: m8792, DP: 199, AD: 1
#   Mutation: m880, DP: 196, AD: 0
#   Mutation: m9119, DP: 181, AD: 0
#   Mutation: m9135, DP: 254, AD: 1
#   Mutation: m9232, DP: 217, AD: 0
#   Mutation: m9247, DP: 221, AD: 1
#   Mutation: m927, DP: 244, AD: 0
#   Mutation: m9322, DP: 154, AD: 1
#   Mutation: m947, DP: 160, AD: 0
#   Mutation: m9472, DP: 196, AD: 0
#   Mutation: m9496, DP: 142, AD: 0
#   Mutation: m9631, DP: 164, AD: 0
#   Mutation: m9721, DP: 234, AD: 1
#   Mutation: m9852, DP: 191, AD: 0
#   Mutation: m9886, DP: 206, AD: 0
#
# Cell ID: 1, Mutation Profile:
#   Mutation: m10069, DP: 211, AD: 0
#   Mutation: m10086, DP: 209, AD: 1
#   Mutation: m10131, DP: 181, AD: 1
#   Mutation: m10182, DP: 120, AD: 0
#   Mutation: m10212, DP: 146, AD: 0
#   Mutation: m10220, DP: 172, AD: 0
#   Mutation: m10289, DP: 243, AD: 0
#   Mutation: m10303, DP: 132, AD: 0
#   Mutation: m10402, DP: 205, AD: 0
#   Mutation: m10588, DP: 189, AD: 0
#   Mutation: m10637, DP: 139, AD: 0
#   Mutation: m10648, DP: 256, AD: 0
#   Mutation: m11060, DP: 138, AD: 0
#   Mutation: m11066, DP: 128, AD: 0
#   Mutation: m11158, DP: 161, AD: 2
#   Mutation: m11180, DP: 222, AD: 1
#   Mutation: m11331, DP: 233, AD: 0
#   Mutation: m11594, DP: 184, AD: 0
#   Mutation: m11800, DP: 182, AD: 0
#   Mutation: m1184, DP: 182, AD: 0
#   Mutation: m12055, DP: 237, AD: 2
#   Mutation: m12156, DP: 180, AD: 1
#   Mutation: m12193, DP: 159, AD: 0
#   Mutation: m12248, DP: 249, AD: 1
#   Mutation: m12254, DP: 182, AD: 1
#   Mutation: m12458, DP: 206, AD: 0
#   Mutation: m12474, DP: 288, AD: 0
#   Mutation: m12494, DP: 170, AD: 0
#   Mutation: m12495, DP: 186, AD: 0
#   Mutation: m12536, DP: 265, AD: 2
#   Mutation: m12689, DP: 215, AD: 0
#   Mutation: m12783, DP: 186, AD: 0
#   Mutation: m12834, DP: 189, AD: 0
#   Mutation: m12842, DP: 298, AD: 0
#   Mutation: m12909, DP: 164, AD: 1
#   Mutation: m12920, DP: 205, AD: 1
#   Mutation: m13011, DP: 229, AD: 0
#   Mutation: m13144, DP: 220, AD: 1
#   Mutation: m13286, DP: 233, AD: 0
#   Mutation: m13360, DP: 195, AD: 1
#   Mutation: m134, DP: 251, AD: 0
#   Mutation: m13408, DP: 272, AD: 0
#   Mutation: m13633, DP: 143, AD: 1
#   Mutation: m13785, DP: 132, AD: 0
#   Mutation: m14013, DP: 228, AD: 1
#   Mutation: m14016, DP: 136, AD: 1
#   Mutation: m14043, DP: 180, AD: 2
#   Mutation: m14049, DP: 171, AD: 1
#   Mutation: m14096, DP: 174, AD: 0
#   Mutation: m14161, DP: 152, AD: 0
#   Mutation: m14240, DP: 233, AD: 0
#   Mutation: m14314, DP: 150, AD: 0
#   Mutation: m14367, DP: 264, AD: 1
#   Mutation: m14403, DP: 170, AD: 0
#   Mutation: m14493, DP: 250, AD: 0
#   Mutation: m14578, DP: 194, AD: 1
#   Mutation: m14887, DP: 228, AD: 1
#   Mutation: m14940, DP: 286, AD: 0
#   Mutation: m15074, DP: 248, AD: 1
#   Mutation: m15183, DP: 282, AD: 0
#   Mutation: m1524, DP: 177, AD: 0
#   Mutation: m15256, DP: 229, AD: 1
#   Mutation: m15563, DP: 170, AD: 2
#   Mutation: m15621, DP: 172, AD: 0
#   Mutation: m15799, DP: 174, AD: 1
#   Mutation: m15940, DP: 213, AD: 0
#   Mutation: m16000, DP: 277, AD: 1
#   Mutation: m16108, DP: 160, AD: 1
#   Mutation: m1613, DP: 180, AD: 0
#   Mutation: m16165, DP: 256, AD: 1
#   Mutation: m16233, DP: 137, AD: 0
#   Mutation: m16359, DP: 188, AD: 0
#   Mutation: m16497, DP: 174, AD: 0
#   Mutation: m1751, DP: 162, AD: 0
#   Mutation: m1842, DP: 270, AD: 1
#   Mutation: m1980, DP: 144, AD: 0
#   Mutation: m2025, DP: 251, AD: 1
#   Mutation: m2056, DP: 220, AD: 0
#   Mutation: m2114, DP: 294, AD: 1
#   Mutation: m2375, DP: 215, AD: 0
#   Mutation: m2546, DP: 227, AD: 0
#   Mutation: m3094, DP: 190, AD: 1
#   Mutation: m3219, DP: 208, AD: 0
#   Mutation: m3321, DP: 172, AD: 0
#   Mutation: m3363, DP: 320, AD: 2
#   Mutation: m3364, DP: 264, AD: 2
#   Mutation: m3454, DP: 208, AD: 0
#   Mutation: m3482, DP: 192, AD: 0
#   Mutation: m349, DP: 185, AD: 0
#   Mutation: m3543, DP: 119, AD: 0
#   Mutation: m3636, DP: 171, AD: 0
#   Mutation: m3767, DP: 166, AD: 0
#   Mutation: m3796, DP: 172, AD: 1
#   Mutation: m3916, DP: 149, AD: 0
#   Mutation: m4200, DP: 125, AD: 0
#   Mutation: m4286, DP: 183, AD: 1
#   Mutation: m4351, DP: 201, AD: 0
#   Mutation: m4369, DP: 194, AD: 0
#   Mutation: m438, DP: 168, AD: 0
#   Mutation: m4439, DP: 203, AD: 0
#   Mutation: m4507, DP: 202, AD: 0
#   Mutation: m454, DP: 163, AD: 1
#   Mutation: m4784, DP: 174, AD: 0
#   Mutation: m4804, DP: 165, AD: 0
#   Mutation: m4812, DP: 144, AD: 0
#   Mutation: m4848, DP: 213, AD: 0
#   Mutation: m4996, DP: 208, AD: 1
#   Mutation: m5054, DP: 171, AD: 1
#   Mutation: m5061, DP: 268, AD: 0
#   Mutation: m5145, DP: 227, AD: 0
#   Mutation: m5190, DP: 299, AD: 0
#   Mutation: m520, DP: 170, AD: 0
#   Mutation: m5221, DP: 168, AD: 0
#   Mutation: m5228, DP: 229, AD: 1
#   Mutation: m5279, DP: 155, AD: 1
#   Mutation: m5323, DP: 113, AD: 0
#   Mutation: m5382, DP: 142, AD: 0
#   Mutation: m5383, DP: 185, AD: 0
#   Mutation: m5384, DP: 190, AD: 1
#   Mutation: m5435, DP: 216, AD: 0
#   Mutation: m5528, DP: 229, AD: 3
#   Mutation: m5529, DP: 211, AD: 1
#   Mutation: m5644, DP: 202, AD: 0
#   Mutation: m5663, DP: 187, AD: 1
#   Mutation: m5695, DP: 171, AD: 0
#   Mutation: m5764, DP: 160, AD: 0
#   Mutation: m5816, DP: 220, AD: 1
#   Mutation: m5851, DP: 183, AD: 1
#   Mutation: m5878, DP: 192, AD: 2
#   Mutation: m5881, DP: 183, AD: 1
#   Mutation: m5956, DP: 196, AD: 0
#   Mutation: m6069, DP: 244, AD: 0
#   Mutation: m6339, DP: 289, AD: 0
#   Mutation: m6393, DP: 202, AD: 0
#   Mutation: m6430, DP: 252, AD: 0
#   Mutation: m644, DP: 225, AD: 0
#   Mutation: m6576, DP: 281, AD: 0
#   Mutation: m6636, DP: 190, AD: 3
#   Mutation: m6638, DP: 172, AD: 0
#   Mutation: m6720, DP: 166, AD: 0
#   Mutation: m681, DP: 178, AD: 0
#   Mutation: m713, DP: 169, AD: 0
#   Mutation: m7132, DP: 222, AD: 0
#   Mutation: m7183, DP: 150, AD: 1
#   Mutation: m7193, DP: 245, AD: 0
#   Mutation: m7209, DP: 298, AD: 0
#   Mutation: m7228, DP: 171, AD: 0
#   Mutation: m7312, DP: 216, AD: 2
#   Mutation: m7318, DP: 164, AD: 0
#   Mutation: m7344, DP: 203, AD: 1
#   Mutation: m7392, DP: 217, AD: 1
#   Mutation: m7412, DP: 179, AD: 1
#   Mutation: m7435, DP: 173, AD: 0
#   Mutation: m7568, DP: 197, AD: 1
#   Mutation: m7582, DP: 169, AD: 1
#   Mutation: m7613, DP: 246, AD: 0
#   Mutation: m7662, DP: 232, AD: 0
#   Mutation: m7761, DP: 229, AD: 0
#   Mutation: m7827, DP: 183, AD: 0
#   Mutation: m7938, DP: 135, AD: 0
#   Mutation: m8308, DP: 164, AD: 1
#   Mutation: m8420, DP: 161, AD: 0
#   Mutation: m8424, DP: 250, AD: 1
#   Mutation: m8474, DP: 147, AD: 1
#   Mutation: m8534, DP: 347, AD: 0
#   Mutation: m8764, DP: 180, AD: 0
#   Mutation: m8792, DP: 138, AD: 1
#   Mutation: m880, DP: 152, AD: 0
#   Mutation: m9119, DP: 225, AD: 0
#   Mutation: m9135, DP: 151, AD: 0
#   Mutation: m9232, DP: 287, AD: 0
#   Mutation: m9247, DP: 206, AD: 1
#   Mutation: m927, DP: 220, AD: 0
#   Mutation: m9322, DP: 144, AD: 0
#   Mutation: m947, DP: 224, AD: 0
#   Mutation: m9472, DP: 203, AD: 1
#   Mutation: m9496, DP: 137, AD: 0
#   Mutation: m9631, DP: 127, AD: 1
#   Mutation: m9721, DP: 146, AD: 1
#   Mutation: m9852, DP: 243, AD: 2
#   Mutation: m9886, DP: 212, AD: 0
#
# Cell ID: 2, Mutation Profile:
#   Mutation: m10069, DP: 268, AD: 1
#   Mutation: m10086, DP: 204, AD: 0
#   Mutation: m10131, DP: 163, AD: 0
#   Mutation: m10182, DP: 142, AD: 1
#   Mutation: m10212, DP: 184, AD: 3
#   Mutation: m10220, DP: 252, AD: 0
#   Mutation: m10289, DP: 170, AD: 1
#   Mutation: m10303, DP: 223, AD: 0
#   Mutation: m10402, DP: 165, AD: 0
#   Mutation: m10588, DP: 258, AD: 0
#   Mutation: m10637, DP: 124, AD: 0
#   Mutation: m10648, DP: 213, AD: 2
#   Mutation: m11060, DP: 286, AD: 0
#   Mutation: m11066, DP: 188, AD: 0
#   Mutation: m11158, DP: 185, AD: 1
#   Mutation: m11180, DP: 166, AD: 3
#   Mutation: m11331, DP: 171, AD: 1
#   Mutation: m11594, DP: 338, AD: 1
#   Mutation: m11800, DP: 198, AD: 1
#   Mutation: m1184, DP: 155, AD: 1
#   Mutation: m12055, DP: 272, AD: 2
#   Mutation: m12156, DP: 211, AD: 0
#   Mutation: m12193, DP: 183, AD: 0
#   Mutation: m12248, DP: 242, AD: 1
#   Mutation: m12254, DP: 130, AD: 0
#   Mutation: m12458, DP: 178, AD: 0
#   Mutation: m12474, DP: 259, AD: 1
#   Mutation: m12494, DP: 227, AD: 0
#   Mutation: m12495, DP: 138, AD: 0
#   Mutation: m12536, DP: 159, AD: 1
#   Mutation: m12689, DP: 211, AD: 1
#   Mutation: m12783, DP: 166, AD: 0
#   Mutation: m12834, DP: 146, AD: 0
#   Mutation: m12842, DP: 157, AD: 1
#   Mutation: m12909, DP: 311, AD: 2
#   Mutation: m12920, DP: 165, AD: 0
#   Mutation: m13011, DP: 228, AD: 0
#   Mutation: m13144, DP: 199, AD: 0
#   Mutation: m13286, DP: 212, AD: 1
#   Mutation: m13360, DP: 277, AD: 1
#   Mutation: m134, DP: 242, AD: 2
#   Mutation: m13408, DP: 178, AD: 0
#   Mutation: m13633, DP: 159, AD: 1
#   Mutation: m13785, DP: 221, AD: 0
#   Mutation: m14013, DP: 153, AD: 0
#   Mutation: m14016, DP: 143, AD: 1
#   Mutation: m14043, DP: 153, AD: 0
#   Mutation: m14049, DP: 164, AD: 0
#   Mutation: m14096, DP: 170, AD: 1
#   Mutation: m14161, DP: 169, AD: 0
#   Mutation: m14240, DP: 198, AD: 0
#   Mutation: m14314, DP: 157, AD: 0
#   Mutation: m14367, DP: 191, AD: 0
#   Mutation: m14403, DP: 191, AD: 1
#   Mutation: m14493, DP: 150, AD: 0
#   Mutation: m14578, DP: 228, AD: 0
#   Mutation: m14887, DP: 150, AD: 1
#   Mutation: m14940, DP: 301, AD: 0
#   Mutation: m15074, DP: 168, AD: 0
#   Mutation: m15183, DP: 258, AD: 0
#   Mutation: m1524, DP: 161, AD: 1
#   Mutation: m15256, DP: 135, AD: 0
#   Mutation: m15563, DP: 186, AD: 0
#   Mutation: m15621, DP: 150, AD: 0
#   Mutation: m15799, DP: 179, AD: 1
#   Mutation: m15940, DP: 184, AD: 0
#   Mutation: m16000, DP: 290, AD: 0
#   Mutation: m16108, DP: 150, AD: 0
#   Mutation: m1613, DP: 232, AD: 1
#   Mutation: m16165, DP: 189, AD: 0
#   Mutation: m16233, DP: 187, AD: 0
#   Mutation: m16359, DP: 234, AD: 1
#   Mutation: m16497, DP: 266, AD: 0
#   Mutation: m1751, DP: 270, AD: 1
#   Mutation: m1842, DP: 163, AD: 0
#   Mutation: m1980, DP: 173, AD: 0
#   Mutation: m2025, DP: 142, AD: 0
#   Mutation: m2056, DP: 168, AD: 0
#   Mutation: m2114, DP: 152, AD: 0
#   Mutation: m2375, DP: 208, AD: 1
#   Mutation: m2546, DP: 154, AD: 0
#   Mutation: m3094, DP: 211, AD: 2
#   Mutation: m3219, DP: 166, AD: 0
#   Mutation: m3321, DP: 207, AD: 0
#   Mutation: m3363, DP: 264, AD: 1
#   Mutation: m3364, DP: 173, AD: 0
#   Mutation: m3454, DP: 153, AD: 0
#   Mutation: m3482, DP: 169, AD: 0
#   Mutation: m349, DP: 147, AD: 0
#   Mutation: m3543, DP: 165, AD: 2
#   Mutation: m3636, DP: 193, AD: 3
#   Mutation: m3767, DP: 248, AD: 0
#   Mutation: m3796, DP: 309, AD: 1
#   Mutation: m3916, DP: 311, AD: 0
#   Mutation: m4200, DP: 203, AD: 2
#   Mutation: m4286, DP: 144, AD: 0
#   Mutation: m4351, DP: 177, AD: 2
#   Mutation: m4369, DP: 188, AD: 0
#   Mutation: m438, DP: 172, AD: 2
#   Mutation: m4439, DP: 158, AD: 0
#   Mutation: m4507, DP: 219, AD: 1
#   Mutation: m454, DP: 240, AD: 1
#   Mutation: m4784, DP: 170, AD: 0
#   Mutation: m4804, DP: 164, AD: 0
#   Mutation: m4812, DP: 248, AD: 0
#   Mutation: m4848, DP: 203, AD: 0
#   Mutation: m4996, DP: 212, AD: 0
#   Mutation: m5054, DP: 145, AD: 1
#   Mutation: m5061, DP: 235, AD: 1
#   Mutation: m5145, DP: 199, AD: 0
#   Mutation: m5190, DP: 141, AD: 0
#   Mutation: m520, DP: 214, AD: 0
#   Mutation: m5221, DP: 135, AD: 1
#   Mutation: m5228, DP: 210, AD: 0
#   Mutation: m5279, DP: 172, AD: 0
#   Mutation: m5323, DP: 232, AD: 1
#   Mutation: m5382, DP: 188, AD: 0
#   Mutation: m5383, DP: 173, AD: 0
#   Mutation: m5384, DP: 208, AD: 0
#   Mutation: m5435, DP: 174, AD: 0
#   Mutation: m5528, DP: 186, AD: 0
#   Mutation: m5529, DP: 110, AD: 0
#   Mutation: m5644, DP: 177, AD: 0
#   Mutation: m5663, DP: 196, AD: 0
#   Mutation: m5695, DP: 226, AD: 0
#   Mutation: m5764, DP: 144, AD: 0
#   Mutation: m5816, DP: 143, AD: 0
#   Mutation: m5851, DP: 299, AD: 2
#   Mutation: m5878, DP: 210, AD: 1
#   Mutation: m5881, DP: 156, AD: 1
#   Mutation: m5956, DP: 183, AD: 1
#   Mutation: m6069, DP: 215, AD: 1
#   Mutation: m6339, DP: 168, AD: 1
#   Mutation: m6393, DP: 155, AD: 0
#   Mutation: m6430, DP: 194, AD: 0
#   Mutation: m644, DP: 232, AD: 0
#   Mutation: m6576, DP: 170, AD: 1
#   Mutation: m6636, DP: 183, AD: 1
#   Mutation: m6638, DP: 191, AD: 0
#   Mutation: m6720, DP: 168, AD: 1
#   Mutation: m681, DP: 234, AD: 0
#   Mutation: m713, DP: 225, AD: 2
#   Mutation: m7132, DP: 182, AD: 0
#   Mutation: m7183, DP: 177, AD: 0
#   Mutation: m7193, DP: 187, AD: 0
#   Mutation: m7209, DP: 150, AD: 0
#   Mutation: m7228, DP: 172, AD: 0
#   Mutation: m7312, DP: 201, AD: 0
#   Mutation: m7318, DP: 188, AD: 1
#   Mutation: m7344, DP: 226, AD: 1
#   Mutation: m7392, DP: 142, AD: 0
#   Mutation: m7412, DP: 184, AD: 1
#   Mutation: m7435, DP: 202, AD: 0
#   Mutation: m7568, DP: 158, AD: 1
#   Mutation: m7582, DP: 252, AD: 0
#   Mutation: m7613, DP: 145, AD: 0
#   Mutation: m7662, DP: 240, AD: 0
#   Mutation: m7761, DP: 240, AD: 1
#   Mutation: m7827, DP: 187, AD: 0
#   Mutation: m7938, DP: 232, AD: 0
#   Mutation: m8308, DP: 228, AD: 1
#   Mutation: m8420, DP: 254, AD: 1
#   Mutation: m8424, DP: 222, AD: 0
#   Mutation: m8474, DP: 293, AD: 0
#   Mutation: m8534, DP: 188, AD: 1
#   Mutation: m8764, DP: 207, AD: 1
#   Mutation: m8792, DP: 169, AD: 1
#   Mutation: m880, DP: 136, AD: 0
#   Mutation: m9119, DP: 195, AD: 0
#   Mutation: m9135, DP: 228, AD: 0
#   Mutation: m9232, DP: 188, AD: 0
#   Mutation: m9247, DP: 157, AD: 0
#   Mutation: m927, DP: 152, AD: 0
#   Mutation: m9322, DP: 269, AD: 1
#   Mutation: m947, DP: 174, AD: 0
#   Mutation: m9472, DP: 226, AD: 0
#   Mutation: m9496, DP: 186, AD: 0
#   Mutation: m9631, DP: 243, AD: 1
#   Mutation: m9721, DP: 161, AD: 0
#   Mutation: m9852, DP: 245, AD: 0
#   Mutation: m9886, DP: 251, AD: 0
#
# Cell ID: 3, Mutation Profile:
#   Mutation: m10069, DP: 168, AD: 0
#   Mutation: m10086, DP: 235, AD: 1
#   Mutation: m10131, DP: 277, AD: 0
#   Mutation: m10182, DP: 177, AD: 3
#   Mutation: m10212, DP: 224, AD: 0
#   Mutation: m10220, DP: 175, AD: 0
#   Mutation: m10289, DP: 168, AD: 1
#   Mutation: m10303, DP: 159, AD: 0
#   Mutation: m10402, DP: 256, AD: 1
#   Mutation: m10588, DP: 148, AD: 2
#   Mutation: m10637, DP: 154, AD: 1
#   Mutation: m10648, DP: 225, AD: 1
#   Mutation: m11060, DP: 230, AD: 0
#   Mutation: m11066, DP: 192, AD: 1
#   Mutation: m11158, DP: 191, AD: 1
#   Mutation: m11180, DP: 195, AD: 1
#   Mutation: m11331, DP: 246, AD: 0
#   Mutation: m11594, DP: 263, AD: 0
#   Mutation: m11800, DP: 234, AD: 2
#   Mutation: m1184, DP: 174, AD: 1
#   Mutation: m12055, DP: 254, AD: 1
#   Mutation: m12156, DP: 241, AD: 1
#   Mutation: m12193, DP: 186, AD: 1
#   Mutation: m12248, DP: 225, AD: 0
#   Mutation: m12254, DP: 235, AD: 0
#   Mutation: m12458, DP: 187, AD: 0
#   Mutation: m12474, DP: 125, AD: 1
#   Mutation: m12494, DP: 178, AD: 0
#   Mutation: m12495, DP: 178, AD: 2
#   Mutation: m12536, DP: 201, AD: 0
#   Mutation: m12689, DP: 363, AD: 2
#   Mutation: m12783, DP: 267, AD: 1
#   Mutation: m12834, DP: 212, AD: 0
#   Mutation: m12842, DP: 212, AD: 0
#   Mutation: m12909, DP: 186, AD: 0
#   Mutation: m12920, DP: 153, AD: 0
#   Mutation: m13011, DP: 168, AD: 0
#   Mutation: m13144, DP: 234, AD: 2
#   Mutation: m13286, DP: 173, AD: 1
#   Mutation: m13360, DP: 186, AD: 0
#   Mutation: m134, DP: 213, AD: 0
#   Mutation: m13408, DP: 234, AD: 0
#   Mutation: m13633, DP: 243, AD: 2
#   Mutation: m13785, DP: 262, AD: 0
#   Mutation: m14013, DP: 252, AD: 1
#   Mutation: m14016, DP: 157, AD: 0
#   Mutation: m14043, DP: 199, AD: 2
#   Mutation: m14049, DP: 212, AD: 1
#   Mutation: m14096, DP: 308, AD: 2
#   Mutation: m14161, DP: 202, AD: 0
#   Mutation: m14240, DP: 168, AD: 0
#   Mutation: m14314, DP: 213, AD: 1
#   Mutation: m14367, DP: 171, AD: 0
#   Mutation: m14403, DP: 148, AD: 1
#   Mutation: m14493, DP: 219, AD: 1
#   Mutation: m14578, DP: 143, AD: 0
#   Mutation: m14887, DP: 200, AD: 0
#   Mutation: m14940, DP: 198, AD: 2
#   Mutation: m15074, DP: 139, AD: 0
#   Mutation: m15183, DP: 235, AD: 0
#   Mutation: m1524, DP: 149, AD: 1
#   Mutation: m15256, DP: 224, AD: 0
#   Mutation: m15563, DP: 180, AD: 1
#   Mutation: m15621, DP: 161, AD: 0
#   Mutation: m15799, DP: 131, AD: 1
#   Mutation: m15940, DP: 277, AD: 0
#   Mutation: m16000, DP: 215, AD: 0
#   Mutation: m16108, DP: 195, AD: 0
#   Mutation: m1613, DP: 123, AD: 0
#   Mutation: m16165, DP: 201, AD: 0
#   Mutation: m16233, DP: 185, AD: 4
#   Mutation: m16359, DP: 238, AD: 1
#   Mutation: m16497, DP: 163, AD: 0
#   Mutation: m1751, DP: 206, AD: 1
#   Mutation: m1842, DP: 194, AD: 0
#   Mutation: m1980, DP: 214, AD: 0
#   Mutation: m2025, DP: 211, AD: 0
#   Mutation: m2056, DP: 199, AD: 0
#   Mutation: m2114, DP: 139, AD: 0
#   Mutation: m2375, DP: 190, AD: 0
#   Mutation: m2546, DP: 272, AD: 1
#   Mutation: m3094, DP: 233, AD: 2
#   Mutation: m3219, DP: 222, AD: 0
#   Mutation: m3321, DP: 183, AD: 0
#   Mutation: m3363, DP: 182, AD: 0
#   Mutation: m3364, DP: 215, AD: 0
#   Mutation: m3454, DP: 188, AD: 0
#   Mutation: m3482, DP: 240, AD: 1
#   Mutation: m349, DP: 224, AD: 0
#   Mutation: m3543, DP: 233, AD: 3
#   Mutation: m3636, DP: 240, AD: 1
#   Mutation: m3767, DP: 216, AD: 0
#   Mutation: m3796, DP: 220, AD: 1
#   Mutation: m3916, DP: 196, AD: 0
#   Mutation: m4200, DP: 274, AD: 0
#   Mutation: m4286, DP: 171, AD: 0
#   Mutation: m4351, DP: 189, AD: 0
#   Mutation: m4369, DP: 172, AD: 0
#   Mutation: m438, DP: 161, AD: 1
#   Mutation: m4439, DP: 194, AD: 2
#   Mutation: m4507, DP: 317, AD: 0
#   Mutation: m454, DP: 295, AD: 2
#   Mutation: m4784, DP: 177, AD: 0
#   Mutation: m4804, DP: 122, AD: 0
#   Mutation: m4812, DP: 157, AD: 0
#   Mutation: m4848, DP: 203, AD: 1
#   Mutation: m4996, DP: 189, AD: 0
#   Mutation: m5054, DP: 203, AD: 1
#   Mutation: m5061, DP: 207, AD: 0
#   Mutation: m5145, DP: 210, AD: 1
#   Mutation: m5190, DP: 120, AD: 0
#   Mutation: m520, DP: 189, AD: 0
#   Mutation: m5221, DP: 227, AD: 1
#   Mutation: m5228, DP: 139, AD: 1
#   Mutation: m5279, DP: 322, AD: 0
#   Mutation: m5323, DP: 120, AD: 0
#   Mutation: m5382, DP: 274, AD: 0
#   Mutation: m5383, DP: 272, AD: 1
#   Mutation: m5384, DP: 200, AD: 1
#   Mutation: m5435, DP: 167, AD: 1
#   Mutation: m5528, DP: 255, AD: 0
#   Mutation: m5529, DP: 179, AD: 0
#   Mutation: m5644, DP: 161, AD: 0
#   Mutation: m5663, DP: 172, AD: 1
#   Mutation: m5695, DP: 249, AD: 0
#   Mutation: m5764, DP: 257, AD: 1
#   Mutation: m5816, DP: 204, AD: 1
#   Mutation: m5851, DP: 160, AD: 0
#   Mutation: m5878, DP: 205, AD: 0
#   Mutation: m5881, DP: 160, AD: 0
#   Mutation: m5956, DP: 166, AD: 1
#   Mutation: m6069, DP: 194, AD: 0
#   Mutation: m6339, DP: 122, AD: 0
#   Mutation: m6393, DP: 224, AD: 2
#   Mutation: m6430, DP: 212, AD: 0
#   Mutation: m644, DP: 184, AD: 1
#   Mutation: m6576, DP: 224, AD: 2
#   Mutation: m6636, DP: 195, AD: 0
#   Mutation: m6638, DP: 217, AD: 1
#   Mutation: m6720, DP: 186, AD: 2
#   Mutation: m681, DP: 171, AD: 1
#   Mutation: m713, DP: 175, AD: 0
#   Mutation: m7132, DP: 270, AD: 0
#   Mutation: m7183, DP: 282, AD: 0
#   Mutation: m7193, DP: 225, AD: 1
#   Mutation: m7209, DP: 190, AD: 0
#   Mutation: m7228, DP: 201, AD: 0
#   Mutation: m7312, DP: 173, AD: 1
#   Mutation: m7318, DP: 218, AD: 0
#   Mutation: m7344, DP: 220, AD: 0
#   Mutation: m7392, DP: 245, AD: 0
#   Mutation: m7412, DP: 234, AD: 1
#   Mutation: m7435, DP: 187, AD: 0
#   Mutation: m7568, DP: 177, AD: 0
#   Mutation: m7582, DP: 242, AD: 0
#   Mutation: m7613, DP: 226, AD: 0
#   Mutation: m7662, DP: 249, AD: 0
#   Mutation: m7761, DP: 267, AD: 0
#   Mutation: m7827, DP: 183, AD: 1
#   Mutation: m7938, DP: 211, AD: 0
#   Mutation: m8308, DP: 165, AD: 0
#   Mutation: m8420, DP: 152, AD: 0
#   Mutation: m8424, DP: 258, AD: 2
#   Mutation: m8474, DP: 196, AD: 0
#   Mutation: m8534, DP: 193, AD: 0
#   Mutation: m8764, DP: 213, AD: 0
#   Mutation: m8792, DP: 216, AD: 0
#   Mutation: m880, DP: 207, AD: 0
#   Mutation: m9119, DP: 181, AD: 2
#   Mutation: m9135, DP: 153, AD: 0
#   Mutation: m9232, DP: 125, AD: 0
#   Mutation: m9247, DP: 247, AD: 0
#   Mutation: m927, DP: 184, AD: 1
#   Mutation: m9322, DP: 245, AD: 0
#   Mutation: m947, DP: 134, AD: 0
#   Mutation: m9472, DP: 163, AD: 0
#   Mutation: m9496, DP: 168, AD: 0
#   Mutation: m9631, DP: 207, AD: 1
#   Mutation: m9721, DP: 170, AD: 1
#   Mutation: m9852, DP: 211, AD: 0
#   Mutation: m9886, DP: 183, AD: 0
#
# Cell ID: 4, Mutation Profile:
#   Mutation: m10069, DP: 167, AD: 0
#   Mutation: m10086, DP: 165, AD: 0
#   Mutation: m10131, DP: 151, AD: 0
#   Mutation: m10182, DP: 144, AD: 0
#   Mutation: m10212, DP: 152, AD: 0
#   Mutation: m10220, DP: 283, AD: 1
#   Mutation: m10289, DP: 194, AD: 0
#   Mutation: m10303, DP: 161, AD: 0
#   Mutation: m10402, DP: 190, AD: 0
#   Mutation: m10588, DP: 198, AD: 0
#   Mutation: m10637, DP: 167, AD: 1
#   Mutation: m10648, DP: 158, AD: 0
#   Mutation: m11060, DP: 210, AD: 0
#   Mutation: m11066, DP: 160, AD: 1
#   Mutation: m11158, DP: 168, AD: 1
#   Mutation: m11180, DP: 143, AD: 1
#   Mutation: m11331, DP: 190, AD: 0
#   Mutation: m11594, DP: 191, AD: 0
#   Mutation: m11800, DP: 156, AD: 0
#   Mutation: m1184, DP: 215, AD: 1
#   Mutation: m12055, DP: 284, AD: 0
#   Mutation: m12156, DP: 306, AD: 1
#   Mutation: m12193, DP: 177, AD: 0
#   Mutation: m12248, DP: 260, AD: 0
#   Mutation: m12254, DP: 186, AD: 0
#   Mutation: m12458, DP: 205, AD: 0
#   Mutation: m12474, DP: 151, AD: 0
#   Mutation: m12494, DP: 227, AD: 0
#   Mutation: m12495, DP: 261, AD: 0
#   Mutation: m12536, DP: 220, AD: 0
#   Mutation: m12689, DP: 157, AD: 0
#   Mutation: m12783, DP: 139, AD: 0
#   Mutation: m12834, DP: 210, AD: 1
#   Mutation: m12842, DP: 206, AD: 0
#   Mutation: m12909, DP: 203, AD: 0
#   Mutation: m12920, DP: 216, AD: 1
#   Mutation: m13011, DP: 215, AD: 0
#   Mutation: m13144, DP: 158, AD: 0
#   Mutation: m13286, DP: 153, AD: 0
#   Mutation: m13360, DP: 234, AD: 2
#   Mutation: m134, DP: 174, AD: 0
#   Mutation: m13408, DP: 260, AD: 1
#   Mutation: m13633, DP: 232, AD: 0
#   Mutation: m13785, DP: 220, AD: 0
#   Mutation: m14013, DP: 167, AD: 0
#   Mutation: m14016, DP: 244, AD: 0
#   Mutation: m14043, DP: 193, AD: 0
#   Mutation: m14049, DP: 121, AD: 0
#   Mutation: m14096, DP: 153, AD: 0
#   Mutation: m14161, DP: 177, AD: 0
#   Mutation: m14240, DP: 183, AD: 0
#   Mutation: m14314, DP: 154, AD: 0
#   Mutation: m14367, DP: 139, AD: 0
#   Mutation: m14403, DP: 161, AD: 0
#   Mutation: m14493, DP: 165, AD: 0
#   Mutation: m14578, DP: 176, AD: 0
#   Mutation: m14887, DP: 166, AD: 0
#   Mutation: m14940, DP: 162, AD: 1
#   Mutation: m15074, DP: 181, AD: 0
#   Mutation: m15183, DP: 163, AD: 0
#   Mutation: m1524, DP: 217, AD: 0
#   Mutation: m15256, DP: 211, AD: 1
#   Mutation: m15563, DP: 183, AD: 0
#   Mutation: m15621, DP: 193, AD: 0
#   Mutation: m15799, DP: 252, AD: 0
#   Mutation: m15940, DP: 155, AD: 0
#   Mutation: m16000, DP: 263, AD: 0
#   Mutation: m16108, DP: 152, AD: 1
#   Mutation: m1613, DP: 223, AD: 0
#   Mutation: m16165, DP: 145, AD: 1
#   Mutation: m16233, DP: 202, AD: 1
#   Mutation: m16359, DP: 241, AD: 1
#   Mutation: m16497, DP: 216, AD: 0
#   Mutation: m1751, DP: 169, AD: 0
#   Mutation: m1842, DP: 236, AD: 0
#   Mutation: m1980, DP: 261, AD: 0
#   Mutation: m2025, DP: 171, AD: 0
#   Mutation: m2056, DP: 251, AD: 1
#   Mutation: m2114, DP: 149, AD: 0
#   Mutation: m2375, DP: 215, AD: 0
#   Mutation: m2546, DP: 180, AD: 0
#   Mutation: m3094, DP: 196, AD: 0
#   Mutation: m3219, DP: 222, AD: 0
#   Mutation: m3321, DP: 147, AD: 1
#   Mutation: m3363, DP: 280, AD: 0
#   Mutation: m3364, DP: 227, AD: 0
#   Mutation: m3454, DP: 172, AD: 0
#   Mutation: m3482, DP: 162, AD: 0
#   Mutation: m349, DP: 256, AD: 0
#   Mutation: m3543, DP: 191, AD: 0
#   Mutation: m3636, DP: 297, AD: 1
#   Mutation: m3767, DP: 212, AD: 1
#   Mutation: m3796, DP: 195, AD: 1
#   Mutation: m3916, DP: 227, AD: 2
#   Mutation: m4200, DP: 193, AD: 1
#   Mutation: m4286, DP: 212, AD: 1
#   Mutation: m4351, DP: 177, AD: 1
#   Mutation: m4369, DP: 213, AD: 1
#   Mutation: m438, DP: 158, AD: 0
#   Mutation: m4439, DP: 187, AD: 0
#   Mutation: m4507, DP: 214, AD: 0
#   Mutation: m454, DP: 194, AD: 0
#   Mutation: m4784, DP: 183, AD: 0
#   Mutation: m4804, DP: 142, AD: 1
#   Mutation: m4812, DP: 144, AD: 0
#   Mutation: m4848, DP: 294, AD: 0
#   Mutation: m4996, DP: 237, AD: 0
#   Mutation: m5054, DP: 269, AD: 2
#   Mutation: m5061, DP: 190, AD: 0
#   Mutation: m5145, DP: 190, AD: 0
#   Mutation: m5190, DP: 251, AD: 0
#   Mutation: m520, DP: 144, AD: 0
#   Mutation: m5221, DP: 207, AD: 1
#   Mutation: m5228, DP: 217, AD: 0
#   Mutation: m5279, DP: 177, AD: 1
#   Mutation: m5323, DP: 225, AD: 0
#   Mutation: m5382, DP: 142, AD: 0
#   Mutation: m5383, DP: 131, AD: 0
#   Mutation: m5384, DP: 151, AD: 0
#   Mutation: m5435, DP: 172, AD: 0
#   Mutation: m5528, DP: 198, AD: 0
#   Mutation: m5529, DP: 265, AD: 1
#   Mutation: m5644, DP: 229, AD: 0
#   Mutation: m5663, DP: 147, AD: 2
#   Mutation: m5695, DP: 163, AD: 0
#   Mutation: m5764, DP: 276, AD: 0
#   Mutation: m5816, DP: 145, AD: 0
#   Mutation: m5851, DP: 204, AD: 2
#   Mutation: m5878, DP: 200, AD: 1
#   Mutation: m5881, DP: 236, AD: 0
#   Mutation: m5956, DP: 277, AD: 1
#   Mutation: m6069, DP: 189, AD: 1
#   Mutation: m6339, DP: 176, AD: 0
#   Mutation: m6393, DP: 294, AD: 2
#   Mutation: m6430, DP: 194, AD: 0
#   Mutation: m644, DP: 195, AD: 1
#   Mutation: m6576, DP: 140, AD: 1
#   Mutation: m6636, DP: 141, AD: 1
#   Mutation: m6638, DP: 132, AD: 0
#   Mutation: m6720, DP: 141, AD: 1
#   Mutation: m681, DP: 186, AD: 0
#   Mutation: m713, DP: 229, AD: 1
#   Mutation: m7132, DP: 167, AD: 0
#   Mutation: m7183, DP: 147, AD: 0
#   Mutation: m7193, DP: 160, AD: 2
#   Mutation: m7209, DP: 225, AD: 0
#   Mutation: m7228, DP: 198, AD: 1
#   Mutation: m7312, DP: 190, AD: 0
#   Mutation: m7318, DP: 128, AD: 0
#   Mutation: m7344, DP: 232, AD: 0
#   Mutation: m7392, DP: 178, AD: 0
#   Mutation: m7412, DP: 116, AD: 0
#   Mutation: m7435, DP: 218, AD: 0
#   Mutation: m7568, DP: 190, AD: 3
#   Mutation: m7582, DP: 166, AD: 0
#   Mutation: m7613, DP: 290, AD: 0
#   Mutation: m7662, DP: 197, AD: 1
#   Mutation: m7761, DP: 231, AD: 0
#   Mutation: m7827, DP: 233, AD: 0
#   Mutation: m7938, DP: 170, AD: 0
#   Mutation: m8308, DP: 190, AD: 1
#   Mutation: m8420, DP: 120, AD: 0
#   Mutation: m8424, DP: 251, AD: 0
#   Mutation: m8474, DP: 246, AD: 0
#   Mutation: m8534, DP: 226, AD: 1
#   Mutation: m8764, DP: 179, AD: 1
#   Mutation: m8792, DP: 283, AD: 2
#   Mutation: m880, DP: 149, AD: 0
#   Mutation: m9119, DP: 261, AD: 1
#   Mutation: m9135, DP: 217, AD: 1
#   Mutation: m9232, DP: 241, AD: 0
#   Mutation: m9247, DP: 230, AD: 0
#   Mutation: m927, DP: 203, AD: 0
#   Mutation: m9322, DP: 164, AD: 0
#   Mutation: m947, DP: 230, AD: 0
#   Mutation: m9472, DP: 144, AD: 0
#   Mutation: m9496, DP: 214, AD: 0
#   Mutation: m9631, DP: 244, AD: 0
#   Mutation: m9721, DP: 326, AD: 1
#   Mutation: m9852, DP: 243, AD: 0
#   Mutation: m9886, DP: 167, AD: 0
#
# Simulated Gene Expression Data (first 5 cells):
#    Gene_0  Gene_1  Gene_2  Gene_3  Gene_4  Gene_5  Gene_6  Gene_7  Gene_8  \
# 0      48      15      13       7       0       0      70       3      53
# 1     213     173       3      13       8      26     149       0      14
# 2      81      66       6      29      55      14      17      15     145
# 3     168     381      13      13      14     121       6      72      36
# 4      56     133       9      64      11      28       4       0      25
#
#    Gene_9  ...  Gene_3990  Gene_3991  Gene_3992  Gene_3993  Gene_3994  \
# 0     113  ...         22         13        101        108        183
# 1      50  ...        184         17        488         49         19
# 2       4  ...         22         11          7         62         40
# 3      44  ...          0         11         25          0         16
# 4       7  ...          0         22         13         68         62
#
#    Gene_3995  Gene_3996  Gene_3997  Gene_3998  Gene_3999
# 0          2         62         55         29          0
# 1          4         47         40         14          4
# 2         53         54         33         12          8
# 3         84        582        172          0          2
# 4         85          0         36          3          1
#
# [5 rows x 4000 columns]

# %%
all_cells[0].mutation_profile
# Out:
# {'m107714': {'DP': 229, 'AD': 0},
#  'm111362': {'DP': 255, 'AD': 1},
#  'm119528': {'DP': 159, 'AD': 1},
#  'm122530': {'DP': 198, 'AD': 0},
#  'm125730': {'DP': 246, 'AD': 0},
#  'm131753': {'DP': 202, 'AD': 0},
#  'm140854': {'DP': 249, 'AD': 0},
#  'm148063': {'DP': 158, 'AD': 0},
#  'm151590': {'DP': 178, 'AD': 0},
#  'm151750': {'DP': 170, 'AD': 1},
#  'm155210': {'DP': 213, 'AD': 1},
#  'm157176': {'DP': 285, 'AD': 2},
#  'm166002': {'DP': 201, 'AD': 0},
#  'm182327': {'DP': 154, 'AD': 0},
#  'm187442': {'DP': 196, 'AD': 1},
#  'm190117': {'DP': 211, 'AD': 0},
#  'm192567': {'DP': 209, 'AD': 0},
#  'm193936': {'DP': 122, 'AD': 0},
#  'm204221': {'DP': 156, 'AD': 1},
#  'm210975': {'DP': 133, 'AD': 1},
#  'm227026': {'DP': 169, 'AD': 1},
#  'm229265': {'DP': 280, 'AD': 1},
#  'm234180': {'DP': 154, 'AD': 2},
#  'm240844': {'DP': 174, 'AD': 0},
#  'm24470': {'DP': 142, 'AD': 0},
#  'm255942': {'DP': 230, 'AD': 1},
#  'm259942': {'DP': 155, 'AD': 1},
#  'm262836': {'DP': 194, 'AD': 2},
#  'm263024': {'DP': 283, 'AD': 0},
#  'm264560': {'DP': 190, 'AD': 0},
#  'm266651': {'DP': 321, 'AD': 1},
#  'm270293': {'DP': 145, 'AD': 1},
#  'm272781': {'DP': 181, 'AD': 0},
#  'm278377': {'DP': 214, 'AD': 1},
#  'm285015': {'DP': 202, 'AD': 0},
#  'm293497': {'DP': 259, 'AD': 0},
#  'm296525': {'DP': 230, 'AD': 0},
#  'm297542': {'DP': 267, 'AD': 2},
#  'm310363': {'DP': 229, 'AD': 0},
#  'm311271': {'DP': 158, 'AD': 0},
#  'm314168': {'DP': 199, 'AD': 1},
#  'm314383': {'DP': 183, 'AD': 1},
#  'm321108': {'DP': 178, 'AD': 1},
#  'm324842': {'DP': 176, 'AD': 0},
#  'm330298': {'DP': 211, 'AD': 2},
#  'm330303': {'DP': 189, 'AD': 0},
#  'm33484': {'DP': 248, 'AD': 1},
#  'm357587': {'DP': 163, 'AD': 0},
#  'm36089': {'DP': 137, 'AD': 0},
#  'm368442': {'DP': 144, 'AD': 0},
#  'm370516': {'DP': 281, 'AD': 0},
#  'm371521': {'DP': 243, 'AD': 0},
#  'm372922': {'DP': 167, 'AD': 0},
#  'm375813': {'DP': 141, 'AD': 0},
#  'm376277': {'DP': 152, 'AD': 0},
#  'm382136': {'DP': 189, 'AD': 1},
#  'm382846': {'DP': 215, 'AD': 0},
#  'm38382': {'DP': 307, 'AD': 3},
#  'm393490': {'DP': 198, 'AD': 0},
#  'm397768': {'DP': 226, 'AD': 0},
#  'm400399': {'DP': 245, 'AD': 0},
#  'm400628': {'DP': 158, 'AD': 1},
#  'm40080': {'DP': 230, 'AD': 0},
#  'm401947': {'DP': 178, 'AD': 0},
#  'm403748': {'DP': 113, 'AD': 0},
#  'm414248': {'DP': 161, 'AD': 0},
#  'm417852': {'DP': 186, 'AD': 0},
#  'm42100': {'DP': 164, 'AD': 0},
#  'm421605': {'DP': 144, 'AD': 0},
#  'm431862': {'DP': 163, 'AD': 0},
#  'm437780': {'DP': 220, 'AD': 0},
#  'm44275': {'DP': 171, 'AD': 1},
#  'm445580': {'DP': 235, 'AD': 0},
#  'm448111': {'DP': 172, 'AD': 1},
#  'm451050': {'DP': 243, 'AD': 0},
#  'm464135': {'DP': 211, 'AD': 2},
#  'm470364': {'DP': 216, 'AD': 1},
#  'm473326': {'DP': 191, 'AD': 0},
#  'm476362': {'DP': 157, 'AD': 0},
#  'm482203': {'DP': 165, 'AD': 0},
#  'm490762': {'DP': 307, 'AD': 0},
#  'm491193': {'DP': 245, 'AD': 0},
#  'm491319': {'DP': 172, 'AD': 0},
#  'm497859': {'DP': 302, 'AD': 0},
#  'm498567': {'DP': 198, 'AD': 1},
#  'm499102': {'DP': 163, 'AD': 0},
#  'm499313': {'DP': 241, 'AD': 0},
#  'm504354': {'DP': 232, 'AD': 1},
#  'm50612': {'DP': 217, 'AD': 0},
#  'm513289': {'DP': 172, 'AD': 0},
#  'm524726': {'DP': 160, 'AD': 0},
#  'm530052': {'DP': 312, 'AD': 3},
#  'm539466': {'DP': 183, 'AD': 2},
#  'm544379': {'DP': 199, 'AD': 0},
#  'm548364': {'DP': 236, 'AD': 0},
#  'm551788': {'DP': 197, 'AD': 0},
#  'm552565': {'DP': 213, 'AD': 2},
#  'm572027': {'DP': 152, 'AD': 1},
#  'm577486': {'DP': 158, 'AD': 0},
#  'm580945': {'DP': 280, 'AD': 1},
#  'm584610': {'DP': 146, 'AD': 0},
#  'm58666': {'DP': 161, 'AD': 1},
#  'm588509': {'DP': 178, 'AD': 0},
#  'm600352': {'DP': 224, 'AD': 0},
#  'm6024': {'DP': 175, 'AD': 0},
#  'm602770': {'DP': 148, 'AD': 0},
#  'm605824': {'DP': 149, 'AD': 1},
#  'm606719': {'DP': 268, 'AD': 1},
#  'm607110': {'DP': 187, 'AD': 0},
#  'm614917': {'DP': 135, 'AD': 1},
#  'm620821': {'DP': 197, 'AD': 0},
#  'm625385': {'DP': 239, 'AD': 1},
#  'm636906': {'DP': 161, 'AD': 0},
#  'm637873': {'DP': 200, 'AD': 1},
#  'm640880': {'DP': 270, 'AD': 0},
#  'm640952': {'DP': 204, 'AD': 2},
#  'm641950': {'DP': 217, 'AD': 0},
#  'm644711': {'DP': 235, 'AD': 0},
#  'm645379': {'DP': 214, 'AD': 0},
#  'm653256': {'DP': 187, 'AD': 2},
#  'm654132': {'DP': 313, 'AD': 1},
#  'm654431': {'DP': 222, 'AD': 0},
#  'm656195': {'DP': 279, 'AD': 0},
#  'm658488': {'DP': 204, 'AD': 0},
#  'm658903': {'DP': 136, 'AD': 0},
#  'm67561': {'DP': 134, 'AD': 0},
#  'm677831': {'DP': 143, 'AD': 0},
#  'm67810': {'DP': 168, 'AD': 1},
#  'm685094': {'DP': 246, 'AD': 0},
#  'm685164': {'DP': 212, 'AD': 2},
#  'm688860': {'DP': 275, 'AD': 0},
#  'm695889': {'DP': 188, 'AD': 0},
#  'm698130': {'DP': 185, 'AD': 1},
#  'm700444': {'DP': 183, 'AD': 0},
#  'm709966': {'DP': 268, 'AD': 1},
#  'm712634': {'DP': 167, 'AD': 2},
#  'm717142': {'DP': 218, 'AD': 0},
#  'm723270': {'DP': 175, 'AD': 1},
#  'm728288': {'DP': 160, 'AD': 0},
#  'm728832': {'DP': 345, 'AD': 0},
#  'm730054': {'DP': 286, 'AD': 0},
#  'm742475': {'DP': 133, 'AD': 1},
#  'm747322': {'DP': 199, 'AD': 0},
#  'm74745': {'DP': 186, 'AD': 0},
#  'm750735': {'DP': 178, 'AD': 0},
#  'm7568': {'DP': 175, 'AD': 0},
#  'm75784': {'DP': 169, 'AD': 0},
#  'm767680': {'DP': 206, 'AD': 0},
#  'm769339': {'DP': 200, 'AD': 0},
#  'm770098': {'DP': 191, 'AD': 1},
#  'm771085': {'DP': 176, 'AD': 0},
#  'm772699': {'DP': 110, 'AD': 0},
#  'm778701': {'DP': 205, 'AD': 1},
#  'm779803': {'DP': 132, 'AD': 0},
#  'm779912': {'DP': 183, 'AD': 0},
#  'm786124': {'DP': 169, 'AD': 1},
#  'm788183': {'DP': 241, 'AD': 0},
#  'm78944': {'DP': 130, 'AD': 0},
#  'm810924': {'DP': 165, 'AD': 2},
#  'm813913': {'DP': 180, 'AD': 0},
#  'm814980': {'DP': 215, 'AD': 0},
#  'm815447': {'DP': 198, 'AD': 2},
#  'm825357': {'DP': 243, 'AD': 0},
#  'm827138': {'DP': 193, 'AD': 2},
#  'm832985': {'DP': 206, 'AD': 0},
#  'm838017': {'DP': 186, 'AD': 0},
#  'm840837': {'DP': 177, 'AD': 0},
#  'm843460': {'DP': 202, 'AD': 0},
#  'm84613': {'DP': 245, 'AD': 1},
#  'm851843': {'DP': 176, 'AD': 0},
#  'm852139': {'DP': 211, 'AD': 0},
#  'm8537': {'DP': 234, 'AD': 0},
#  'm85687': {'DP': 251, 'AD': 0},
#  'm861599': {'DP': 179, 'AD': 0},
#  'm867683': {'DP': 162, 'AD': 0},
#  'm868666': {'DP': 148, 'AD': 0},
#  'm872139': {'DP': 248, 'AD': 2},
#  'm87410': {'DP': 175, 'AD': 0},
#  'm875092': {'DP': 207, 'AD': 1},
#  'm879854': {'DP': 190, 'AD': 1},
#  'm880020': {'DP': 179, 'AD': 0},
#  'm880952': {'DP': 153, 'AD': 1},
#  'm886378': {'DP': 192, 'AD': 0},
#  'm889105': {'DP': 168, 'AD': 0},
#  'm889393': {'DP': 147, 'AD': 0},
#  'm889975': {'DP': 202, 'AD': 1},
#  'm898568': {'DP': 174, 'AD': 1},
#  'm904092': {'DP': 206, 'AD': 0},
#  'm904438': {'DP': 191, 'AD': 0},
#  'm910621': {'DP': 162, 'AD': 0},
#  'm919820': {'DP': 216, 'AD': 1},
#  'm920975': {'DP': 190, 'AD': 0},
#  'm923320': {'DP': 165, 'AD': 0},
#  'm932118': {'DP': 182, 'AD': 0},
#  'm935209': {'DP': 137, 'AD': 0},
#  'm940226': {'DP': 166, 'AD': 0},
#  'm94535': {'DP': 217, 'AD': 1},
#  'm949513': {'DP': 192, 'AD': 0},
#  'm950956': {'DP': 220, 'AD': 0},
#  'm954039': {'DP': 161, 'AD': 0},
#  'm955333': {'DP': 132, 'AD': 1},
#  'm956153': {'DP': 178, 'AD': 0},
#  'm957718': {'DP': 129, 'AD': 0},
#  'm960570': {'DP': 202, 'AD': 0},
#  'm962596': {'DP': 235, 'AD': 1},
#  'm962694': {'DP': 185, 'AD': 0},
#  'm967158': {'DP': 262, 'AD': 0},
#  'm971301': {'DP': 186, 'AD': 1},
#  'm974362': {'DP': 155, 'AD': 0},
#  'm977861': {'DP': 223, 'AD': 0},
#  'm981343': {'DP': 252, 'AD': 0},
#  'm988735': {'DP': 162, 'AD': 2},
#  'm994025': {'DP': 173, 'AD': 0},
#  'm998980': {'DP': 284, 'AD': 0},
#  'm999770': {'DP': 162, 'AD': 0}}

# %% [markdown]
# ### **8. Code Explanation**
#
# - **Class Definitions**:
#   - `mtDNA` class represents individual mtDNA molecules, tracking their mutations.
#   - `Cell` class represents cells in the simulation, storing lineage information and cell type.
#
# - **mtDNA Dynamics Functions**:
#   - `introduce_mutations` introduces mutations into mtDNA molecules during replication.
#   - `replicate_and_segregate_mtDNA` handles mtDNA replication and random segregation into daughter cells.
#
# - **Cell Growth and Differentiation Functions**:
#   - `simulate_stem_cell_growth` models stem cell divisions using the Gillespie algorithm.
#   - `simulate_cell_differentiation` models differentiation of stem cells into progenitor cells and further into differentiated cells.
#   - `progenitor_asymmetric_division` simulates asymmetric division of progenitor cells.
#
# - **Gene Expression Simulation Functions**:
#   - `generate_gene_params` initializes gene-specific parameters for the simulation.
#   - `generate_latent_expression` computes the latent expression levels \( z_t \) for genes in a cell.
#   - `sample_expression` samples gene expression counts from a ZINB distribution.
#   - `simulate_gene_expression_for_cells` simulates gene expression data for all cells.
#
# - **Main Execution**:
#   - The simulation proceeds through stem cell growth, differentiation, parameter generation, and gene expression simulation.
#   - The final gene expression data is stored in `expression_df`.
#
# #### **Simulating Read Depth (DP and AD)**
#
# - **Function `simulate_read_depth`**:
#   - For each cell, we calculate the heteroplasmy levels of mutations.
#   - Total read depth (DP) for each mutation site is simulated using a Negative Binomial distribution to model overdispersion in sequencing coverage.
#   - Allele depth (AD) is simulated using a Binomial distribution based on the heteroplasmy level and the total read depth.
#   - Sequencing errors are included by adjusting the effective heteroplasmy with the base error rate.
#
# #### **Parameters Used**
#
# - **`mean_dp`**: The average total read depth per mutation site. This value can be adjusted to reflect different sequencing depths.
# - **`dp_dispersion`**: Controls the variance of the total read depth. A higher value indicates more overdispersion.
# - **`base_error_rate`**: The probability of a sequencing error at any given base. This affects the observed allele depth, particularly for low-frequency mutations.
#
# #### **Storing DP and AD**
#
# - Each cell's mitochondrial mutation profile is stored in the `mutation_profile` attribute, which is a dictionary mapping mutations to their DP and AD values.
#
# ---
#
# ### **9. Results and Interpretation**
#
# - **Gene Expression Data**:
#   - The simulated gene expression data (`expression_df`) contains realistic counts that mimic single-cell RNA-seq data.
#   - The data reflects cell-type-specific expression patterns due to the inclusion of cell-type-specific genes.
#
# - **Cell Type Distribution**:
#   - The simulation tracks the number of cells in each cell type, allowing for analysis of differentiation dynamics.
