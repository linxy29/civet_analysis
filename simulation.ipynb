# %% [markdown]
# **Simulation Design for Mitochondrial Lineage Tracing and Single-Cell Transcriptomic Data**
#
# ### **1. Overview**
#
# The simulation consists of four main components:
#
# 1. **Stem Cell Growth Simulation**: Modeling the proliferation of stem cells using the Gillespie algorithm.
# 2. **Mitochondrial Genome Proliferation**: Simulating mtDNA replication, mutation accumulation, and segregation during cell division.
# 3. **Cell Differentiation Simulation**: Modeling asymmetric division of progenitor cells and differentiation into various cell types.
# 4. **Single-Cell Transcriptomic Data Simulation**: Generating gene expression data using latent variables and sampling from a Zero-Inflated Negative Binomial (ZINB) distribution.
#
# ---
#
# ### **2. Simulation of Stem Cell Growth**
#
# **2.1. Model Description**
#
# We simulate stem cell growth by conceptualizing cell division as a continuous-time Markov process. The division rate \( p(t) \) of a stem cell at time \( t \) is defined as:
#
# $$
# p(t) = r \left(1 - \frac{1}{1 + e^{-\kappa (t - t_0)}}\right),
# $$
#
# where:
#
# - \( r \) is the maximum division rate.
# - \( \kappa \) controls the rate at which the growth accelerates.
# - \( t_0 \) represents the inflection point in time when the growth rate changes significantly.
#
# **2.2. Simulation Implementation**
#
# We use the Gillespie stochastic simulation algorithm to model the timing of cell divisions. Starting from a single stem cell, we simulate cell divisions until the desired population size is reached.
#
# ---
#
# ### **3. Simulation of Mitochondrial Genome Proliferation**
#
# **3.1. Initial mtDNA Population**
#
# Each stem cell contains an initial population of mtDNA molecules. We simulate the replication and death of mtDNA molecules within the cell until a target copy number (e.g., 500 copies) is reached.
#
# **3.2. mtDNA Replication and Mutation**
#
# During cell division, mtDNA molecules replicate, and mutations can occur. The key aspects of the mtDNA dynamics include:
#
# - **Replication**: Each mtDNA molecule replicates once.
# - **Mutation Accumulation**: Mutations occur during replication, with the number of mutations following a Poisson distribution.
# - **Segregation**: mtDNA molecules are randomly segregated into daughter cells during cell division.
#
# **3.3. Mutation Rate Estimation**
#
# Assuming a per-mitosis mutation rate for mtDNA that is higher than nuclear DNA, we estimate the expected number of mtDNA mutations per cell division:
#
# $$
# \text{Expected mutations per division} = \mu \times \text{mtDNA copies},
# $$
#
# where \( \mu \) is the mutation rate per mtDNA molecule per division.
#
# ---
#
# ### **4. Simulation of Cell Differentiation**
#
# **4.1. Differentiation Models**
#
# After stem cell growth, cells differentiate according to specified models:
#
# - **Linear Differentiation**: Stem cells differentiate into progenitor cells, which further differentiate into a single cell type.
# - **Bifurcated Differentiation**: Progenitor cells differentiate into multiple cell types.
#
# **4.2. Asymmetric Division of Progenitor Cells**
#
# Progenitor cells undergo asymmetric division:
#
# - One daughter cell remains a progenitor cell capable of self-renewal and further differentiation.
# - The other daughter cell differentiates into a specialized cell type and no longer divides.
#
# **4.3. Differentiation Probability**
#
# Cell differentiation is modeled as a continuous-time Markov process, with a differentiation probability \( q_{ij}(t) \) at time \( t \):
#
# $$
# q_{ij}(t) = 1 - p_i(t),
# $$
#
# where \( p_i(t) \) is the probability that a cell remains in its current state.
#
# ---
#
# ### **5. Simulation of Single-Cell Transcriptomic Data**
#
# **5.1. Gene Expression Model**
#
# We simulate gene expression for each cell, accounting for cell-type-specific and shared genes:
#
# - **Cell-Type-Specific Genes**: Comprise 40% of the simulated genes, following distinct expression programs in different cell types.
# - **Shared Genes**: The remaining genes, with consistent expression across cell types.
#
# **5.2. Two-Step Expression Simulation**
#
# 1. **Latent Expression Generation**:
#
#    For each gene, we generate a latent expression variable \( z_t \) for cell generation \( t \):
#
#    $$
#    z_t \sim \text{Normal}(\mu_t, \sigma^2),
#    $$
#
#    where \( \mu_t \) is the mean expression level dependent on the cell's generation and cell type.
#
# 2. **Sampling Expression Data**:
#
#    The observed gene expression \( x_t \) is sampled from a Zero-Inflated Negative Binomial distribution:
#
#    $$
#    x_t \sim \text{ZINB}(\lambda = e^{z_t}, \theta, \pi),
#    $$
#
#    where:
#
#    - \( \lambda \) is the mean expression level.
#    - \( \theta \) is the dispersion parameter.
#    - \( \pi \) is the zero-inflation probability.
#
# **5.3. Parameters**
#
# - **Base Expression Levels**: Randomly assigned for each gene.
# - **Expression Rates**: Define how gene expression changes with cell generation.
# - **Dispersion and Zero-Inflation Parameters**: Set to mimic realistic single-cell RNA-seq data.
#
# ---
#
# ### **6. Simulation of Sequencing Read Depth for Mitochondrial Mutations**
#
# **6.1. Motivation**
#
# In sequencing data, the total read depth (DP) represents the number of sequencing reads covering a particular genomic position, while the allele depth (AD) represents the number of reads supporting a specific allele (e.g., a mutation) at that position. Including DP and AD in our simulation allows us to model the stochastic nature of sequencing and the variability in detecting mitochondrial mutations.
#
# **6.2. Modeling Read Depth**
#
# For each mitochondrial mutation in each cell:
#
# - **Total Read Depth (DP)**: Simulated using a suitable distribution (e.g., Poisson or Negative Binomial) to reflect variability in sequencing coverage.
# - **Allele Read Depth (AD)**: Simulated based on the heteroplasmy level of the mutation and the total read depth.
#
# **6.3. Implementation Details**
#
# - **Per-Mutation DP Simulation**: We simulate the DP for each mutation site in each cell.
# - **AD Calculation**: Given the DP and the heteroplasmy level (proportion of mtDNA molecules carrying the mutation), we simulate the AD using a binomial distribution.
# - **Error Modeling**: We can include sequencing errors by introducing a base error rate, affecting the observed AD.
#
# ---
#
# ### **7. Python Code Implementation**
#
# Below is the complete Python code implementing the simulation design. Explanations are provided within the code comments.

# %%
import numpy as np
import pandas as pd
import random
from collections import deque

# Set random seed for reproducibility
np.random.seed(42)

# --- Simulation Parameters ---

# Stem cell growth parameters
r = 1.0        # Maximum division rate
kappa = 0.1    # Growth acceleration rate
t0 = 50        # Inflection point in time

# mtDNA parameters
mtDNA_initial_count = 500
mtDNA_mutation_rate_per_mitosis = 0.4   # Mutations per cell division

# Sequencing read depth parameters
mean_dp = 100     # Mean total read depth per mutation site
dp_dispersion = 0.2  # Dispersion parameter for total read depth (overdispersion)
base_error_rate = 0.001  # Sequencing error rate

# Cell differentiation parameters
kappa_diff = 0.1  # Differentiation rate parameter
t0_diff = 50      # Differentiation inflection time

# Gene expression parameters
num_genes = 4000
cell_type_specific_genes = int(num_genes * 0.4)
shared_genes = num_genes - cell_type_specific_genes
alpha = 0.1  # Dispersion parameter for Negative Binomial
zero_inflation_prob = 0.1  # Probability of zero-inflation in gene expression

# Simulation settings
total_cells = 1000  # Total number of stem cells to simulate
max_generations = 10  # Max generations for stem cell divisions

# --- Class Definitions ---

class mtDNA:
    def __init__(self, id, mutations=None):
        self.id = id
        self.mutations = set(mutations) if mutations else set()

class Cell:
    def __init__(self, id, parent_id, generation, time, mtDNA_list=None, cell_type='StemCell'):
        self.id = id
        self.parent_id = parent_id
        self.generation = generation
        self.time = time
        self.mtDNA_list = mtDNA_list if mtDNA_list else []
        self.cell_type = cell_type
        self.children = []
        self.mutation_profile = {}  # To store DP and AD for mutations

# --- Functions for mtDNA Dynamics ---

def introduce_mutations(mtDNA_list, mutation_rate):
    """Introduce mutations into mtDNA molecules."""
    for mt in mtDNA_list:
        num_mutations = np.random.poisson(mutation_rate)
        for _ in range(num_mutations):
            mutation = f"m{np.random.randint(16500)}"
            mt.mutations.add(mutation)
    return mtDNA_list

def replicate_and_segregate_mtDNA(mtDNA_list):
    """Replicate and segregate mtDNA during cell division."""
    # Replicate mtDNA
    replicated_mtDNA = []
    for mt in mtDNA_list:
        replicated_mtDNA.append(mt)
        replicated_mtDNA.append(mtDNA(mt.id, mt.mutations.copy()))
    # Introduce mutations
    mutation_rate = mtDNA_mutation_rate_per_mitosis / len(replicated_mtDNA)
    replicated_mtDNA = introduce_mutations(replicated_mtDNA, mutation_rate)
    # Segregate mtDNA to daughter cells
    total_mtDNA = len(replicated_mtDNA)
    segregation_counts = np.random.multinomial(total_mtDNA, [0.5, 0.5])
    indices = np.random.permutation(total_mtDNA)
    daughter1_indices = indices[:segregation_counts[0]]
    daughter2_indices = indices[segregation_counts[0]:]
    daughter1_mtDNA = [replicated_mtDNA[i] for i in daughter1_indices]
    daughter2_mtDNA = [replicated_mtDNA[i] for i in daughter2_indices]
    return [daughter1_mtDNA, daughter2_mtDNA]

# --- Functions for Cell Growth and Differentiation ---

def division_rate(t, r, kappa, t0):
    """Calculate cell division rate at time t."""
    return r * (1 - 1 / (1 + np.exp(-kappa * (t - t0))))

def differentiation_probability(t, kappa_diff, t0_diff):
    """Calculate cell differentiation probability at time t."""
    return 1 - (1 / (1 + np.exp(-kappa_diff * (t - t0_diff))))

def simulate_stem_cell_growth():
    """Simulate stem cell growth using the Gillespie algorithm."""
    cells = []
    cell_id_counter = 0
    time = 0.0
    cell_queue = deque()

    # Initialize the first cell
    mtDNA_population = [mtDNA(i) for i in range(mtDNA_initial_count)]
    initial_cell = Cell(cell_id_counter, None, 0, time, mtDNA_population.copy(), 'StemCell')
    cells.append(initial_cell)
    cell_queue.append(initial_cell)
    cell_id_counter += 1

    # Simulate stem cell divisions
    while len(cells) < total_cells:
        current_cell = cell_queue.popleft()
        # Calculate division time
        div_rate = division_rate(current_cell.time, r, kappa, t0)
        division_t = np.random.exponential(scale=1.0 / div_rate)
        time += division_t

        # Replicate and segregate mtDNA
        daughter_mtDNAs = replicate_and_segregate_mtDNA(current_cell.mtDNA_list)

        # Create daughter cells
        for i in range(2):
            new_cell = Cell(
                cell_id_counter,
                current_cell.id,
                current_cell.generation + 1,
                time,
                daughter_mtDNAs[i],
                'StemCell'
            )
            cells.append(new_cell)
            cell_queue.append(new_cell)
            current_cell.children.append(new_cell.id)
            cell_id_counter += 1
    return cells

def simulate_cell_differentiation(cells):
    """Simulate cell differentiation after stem cell growth."""
    differentiated_cells = []
    progenitor_cells = []
    for cell in cells:
        if cell.cell_type == 'StemCell':
            # Decide whether the stem cell differentiates into a progenitor cell
            diff_prob = differentiation_probability(cell.time, kappa_diff, t0_diff)
            if np.random.rand() < diff_prob:
                cell.cell_type = 'Progenitor'
                progenitor_cells.append(cell)
        elif cell.cell_type == 'Progenitor':
            # Progenitor cells divide asymmetrically
            daughter_cells = progenitor_asymmetric_division(cell)
            differentiated_cells.extend(daughter_cells)
    return cells + differentiated_cells

def progenitor_asymmetric_division(cell):
    """Simulate asymmetric division of progenitor cells."""
    # Replicate and segregate mtDNA
    daughter_mtDNAs = replicate_and_segregate_mtDNA(cell.mtDNA_list)

    # One daughter remains progenitor
    progenitor_daughter = Cell(
        cell.id * 2,
        cell.id,
        cell.generation + 1,
        cell.time + 1,
        daughter_mtDNAs[0],
        'Progenitor'
    )

    # The other daughter differentiates
    differentiated_daughter = Cell(
        cell.id * 2 + 1,
        cell.id,
        cell.generation + 1,
        cell.time + 1,
        daughter_mtDNAs[1],
        'DifferentiatedType1'  # Assuming linear differentiation
    )

    return [progenitor_daughter, differentiated_daughter]

# --- Functions for Sequencing Read Depth Simulation ---

def simulate_read_depth(cell, all_mutations):
    """Simulate DP and AD for mitochondrial mutations in a cell."""
    mutation_index = {mutation: idx for idx, mutation in enumerate(all_mutations)}
    num_mutations = len(all_mutations)
    mtDNA_count = len(cell.mtDNA_list)

    # Calculate heteroplasmy levels
    mutation_counts = {}
    for mt in cell.mtDNA_list:
        for mutation in mt.mutations:
            mutation_counts[mutation] = mutation_counts.get(mutation, 0) + 1

    heteroplasmy = {mutation: count / mtDNA_count for mutation, count in mutation_counts.items()}

    # Simulate total read depth (DP) for each mutation site
    dp_values = np.random.negative_binomial(
        n=1 / dp_dispersion,
        p=1 / (1 + mean_dp * dp_dispersion),
        size=num_mutations
    )

    dp_values = dp_values + mean_dp  # Adjusting to have mean around mean_dp

    # Simulate allele depth (AD) based on heteroplasmy and DP
    ad_values = []
    dp_list = []
    for idx, mutation in enumerate(all_mutations):
        dp = max(int(dp_values[idx]), 1)  # Ensure at least 1 read
        dp_list.append(dp)
        h = heteroplasmy.get(mutation, base_error_rate)  # Use error rate if mutation not present
        # Include sequencing errors
        effective_h = h * (1 - base_error_rate) + (1 - h) * base_error_rate
        ad = np.random.binomial(dp, effective_h)
        ad_values.append(ad)

    # Store DP and AD in cell's mutation_profile
    cell.mutation_profile = {
        mutation: {'DP': dp_list[idx], 'AD': ad_values[idx]}
        for idx, mutation in enumerate(all_mutations)
    }

# --- Functions for Gene Expression Simulation ---

def generate_gene_params():
    """Generate parameters for gene expression simulation."""
    gene_ids = [f'Gene_{i}' for i in range(num_genes)]
    specific_gene_ids = random.sample(gene_ids, cell_type_specific_genes)
    shared_gene_ids = list(set(gene_ids) - set(specific_gene_ids))

    gene_params = {}
    for gene_id in gene_ids:
        if gene_id in specific_gene_ids:
            gene_params[gene_id] = {
                'base_expression': np.random.uniform(1, 5),
                'expression_rate': np.random.uniform(0.1, 0.5),
                'sigma': 1.0
            }
        else:
            gene_params[gene_id] = {
                'base_expression': np.random.uniform(1, 5),
                'expression_rate': 0.0,
                'sigma': 1.0
            }
    return gene_params

def generate_latent_expression(cell, gene_params):
    """Generate latent expression values for a cell."""
    z_t = {}
    for gene_id, params in gene_params.items():
        loc = params['base_expression'] + params['expression_rate'] * cell.generation
        scale = params['sigma']
        z_t[gene_id] = np.random.normal(loc=loc, scale=scale)
    return z_t

def sample_expression(z_t, alpha, zero_inflation_prob):
    """Sample gene expression counts from a ZINB distribution."""
    x_t = {}
    for gene_id, z in z_t.items():
        mu = np.exp(z)
        r = 1 / alpha
        p = r / (r + mu)
        if np.random.rand() < zero_inflation_prob:
            x_t[gene_id] = 0
        else:
            x_t[gene_id] = np.random.negative_binomial(n=r, p=p)
    return x_t

def simulate_gene_expression_for_cells(cells, gene_params):
    """Simulate gene expression for a list of cells."""
    expression_data = {}
    for cell in cells:
        z_t = generate_latent_expression(cell, gene_params)
        x_t = sample_expression(z_t, alpha, zero_inflation_prob)
        expression_data[cell.id] = x_t
    expression_df = pd.DataFrame.from_dict(expression_data, orient='index')
    return expression_df

# --- Main Simulation Execution ---

# Step 1: Simulate stem cell growth
stem_cells = simulate_stem_cell_growth()

# Step 2: Simulate cell differentiation
all_cells = simulate_cell_differentiation(stem_cells)

# Step 3: Collect all unique mutations across cells
all_mutations = set()
for cell in all_cells:
    for mt in cell.mtDNA_list:
        all_mutations.update(mt.mutations)
all_mutations = sorted(all_mutations)

# Step 4: Simulate sequencing read depth (DP and AD) for mitochondrial mutations
for cell in all_cells:
    simulate_read_depth(cell, all_mutations)

# Step 5: Generate gene expression parameters
gene_params = generate_gene_params()

# Step 6: Simulate gene expression
expression_df = simulate_gene_expression_for_cells(all_cells, gene_params)

# --- Data Output and Visualization ---

# Example: Display DP and AD for the first 5 cells
print("Mitochondrial Mutation Profiles (first 5 cells):")
for cell in all_cells[:5]:
    print(f"Cell ID: {cell.id}, Mutation Profile:")
    for mutation, counts in cell.mutation_profile.items():
        print(f"  Mutation: {mutation}, DP: {counts['DP']}, AD: {counts['AD']}")
    print()

# Example: Display gene expression data for the first 5 cells
print("Simulated Gene Expression Data (first 5 cells):")
print(expression_df.head())
# Out:
# /tmp/ipykernel_26287/3758315817.py:118: RuntimeWarning: divide by zero encountered in scalar divide
#   division_t = np.random.exponential(scale=1.0 / div_rate)
# Mitochondrial Mutation Profiles (first 5 cells):
# Cell ID: 0, Mutation Profile:
#   Mutation: m107714, DP: 229, AD: 0
#   Mutation: m111362, DP: 255, AD: 1
#   Mutation: m119528, DP: 159, AD: 1
#   Mutation: m122530, DP: 198, AD: 0
#   Mutation: m125730, DP: 246, AD: 0
#   Mutation: m131753, DP: 202, AD: 0
#   Mutation: m140854, DP: 249, AD: 0
#   Mutation: m148063, DP: 158, AD: 0
#   Mutation: m151590, DP: 178, AD: 0
#   Mutation: m151750, DP: 170, AD: 1
#   Mutation: m155210, DP: 213, AD: 1
#   Mutation: m157176, DP: 285, AD: 2
#   Mutation: m166002, DP: 201, AD: 0
#   Mutation: m182327, DP: 154, AD: 0
#   Mutation: m187442, DP: 196, AD: 1
#   Mutation: m190117, DP: 211, AD: 0
#   Mutation: m192567, DP: 209, AD: 0
#   Mutation: m193936, DP: 122, AD: 0
#   Mutation: m204221, DP: 156, AD: 1
#   Mutation: m210975, DP: 133, AD: 1
#   Mutation: m227026, DP: 169, AD: 1
#   Mutation: m229265, DP: 280, AD: 1
#   Mutation: m234180, DP: 154, AD: 2
#   Mutation: m240844, DP: 174, AD: 0
#   Mutation: m24470, DP: 142, AD: 0
#   Mutation: m255942, DP: 230, AD: 1
#   Mutation: m259942, DP: 155, AD: 1
#   Mutation: m262836, DP: 194, AD: 2
#   Mutation: m263024, DP: 283, AD: 0
#   Mutation: m264560, DP: 190, AD: 0
#   Mutation: m266651, DP: 321, AD: 1
#   Mutation: m270293, DP: 145, AD: 1
#   Mutation: m272781, DP: 181, AD: 0
#   Mutation: m278377, DP: 214, AD: 1
#   Mutation: m285015, DP: 202, AD: 0
#   Mutation: m293497, DP: 259, AD: 0
#   Mutation: m296525, DP: 230, AD: 0
#   Mutation: m297542, DP: 267, AD: 2
#   Mutation: m310363, DP: 229, AD: 0
#   Mutation: m311271, DP: 158, AD: 0
#   Mutation: m314168, DP: 199, AD: 1
#   Mutation: m314383, DP: 183, AD: 1
#   Mutation: m321108, DP: 178, AD: 1
#   Mutation: m324842, DP: 176, AD: 0
#   Mutation: m330298, DP: 211, AD: 2
#   Mutation: m330303, DP: 189, AD: 0
#   Mutation: m33484, DP: 248, AD: 1
#   Mutation: m357587, DP: 163, AD: 0
#   Mutation: m36089, DP: 137, AD: 0
#   Mutation: m368442, DP: 144, AD: 0
#   Mutation: m370516, DP: 281, AD: 0
#   Mutation: m371521, DP: 243, AD: 0
#   Mutation: m372922, DP: 167, AD: 0
#   Mutation: m375813, DP: 141, AD: 0
#   Mutation: m376277, DP: 152, AD: 0
#   Mutation: m382136, DP: 189, AD: 1
#   Mutation: m382846, DP: 215, AD: 0
#   Mutation: m38382, DP: 307, AD: 3
#   Mutation: m393490, DP: 198, AD: 0
#   Mutation: m397768, DP: 226, AD: 0
#   Mutation: m400399, DP: 245, AD: 0
#   Mutation: m400628, DP: 158, AD: 1
#   Mutation: m40080, DP: 230, AD: 0
#   Mutation: m401947, DP: 178, AD: 0
#   Mutation: m403748, DP: 113, AD: 0
#   Mutation: m414248, DP: 161, AD: 0
#   Mutation: m417852, DP: 186, AD: 0
#   Mutation: m42100, DP: 164, AD: 0
#   Mutation: m421605, DP: 144, AD: 0
#   Mutation: m431862, DP: 163, AD: 0
#   Mutation: m437780, DP: 220, AD: 0
#   Mutation: m44275, DP: 171, AD: 1
#   Mutation: m445580, DP: 235, AD: 0
#   Mutation: m448111, DP: 172, AD: 1
#   Mutation: m451050, DP: 243, AD: 0
#   Mutation: m464135, DP: 211, AD: 2
#   Mutation: m470364, DP: 216, AD: 1
#   Mutation: m473326, DP: 191, AD: 0
#   Mutation: m476362, DP: 157, AD: 0
#   Mutation: m482203, DP: 165, AD: 0
#   Mutation: m490762, DP: 307, AD: 0
#   Mutation: m491193, DP: 245, AD: 0
#   Mutation: m491319, DP: 172, AD: 0
#   Mutation: m497859, DP: 302, AD: 0
#   Mutation: m498567, DP: 198, AD: 1
#   Mutation: m499102, DP: 163, AD: 0
#   Mutation: m499313, DP: 241, AD: 0
#   Mutation: m504354, DP: 232, AD: 1
#   Mutation: m50612, DP: 217, AD: 0
#   Mutation: m513289, DP: 172, AD: 0
#   Mutation: m524726, DP: 160, AD: 0
#   Mutation: m530052, DP: 312, AD: 3
#   Mutation: m539466, DP: 183, AD: 2
#   Mutation: m544379, DP: 199, AD: 0
#   Mutation: m548364, DP: 236, AD: 0
#   Mutation: m551788, DP: 197, AD: 0
#   Mutation: m552565, DP: 213, AD: 2
#   Mutation: m572027, DP: 152, AD: 1
#   Mutation: m577486, DP: 158, AD: 0
#   Mutation: m580945, DP: 280, AD: 1
#   Mutation: m584610, DP: 146, AD: 0
#   Mutation: m58666, DP: 161, AD: 1
#   Mutation: m588509, DP: 178, AD: 0
#   Mutation: m600352, DP: 224, AD: 0
#   Mutation: m6024, DP: 175, AD: 0
#   Mutation: m602770, DP: 148, AD: 0
#   Mutation: m605824, DP: 149, AD: 1
#   Mutation: m606719, DP: 268, AD: 1
#   Mutation: m607110, DP: 187, AD: 0
#   Mutation: m614917, DP: 135, AD: 1
#   Mutation: m620821, DP: 197, AD: 0
#   Mutation: m625385, DP: 239, AD: 1
#   Mutation: m636906, DP: 161, AD: 0
#   Mutation: m637873, DP: 200, AD: 1
#   Mutation: m640880, DP: 270, AD: 0
#   Mutation: m640952, DP: 204, AD: 2
#   Mutation: m641950, DP: 217, AD: 0
#   Mutation: m644711, DP: 235, AD: 0
#   Mutation: m645379, DP: 214, AD: 0
#   Mutation: m653256, DP: 187, AD: 2
#   Mutation: m654132, DP: 313, AD: 1
#   Mutation: m654431, DP: 222, AD: 0
#   Mutation: m656195, DP: 279, AD: 0
#   Mutation: m658488, DP: 204, AD: 0
#   Mutation: m658903, DP: 136, AD: 0
#   Mutation: m67561, DP: 134, AD: 0
#   Mutation: m677831, DP: 143, AD: 0
#   Mutation: m67810, DP: 168, AD: 1
#   Mutation: m685094, DP: 246, AD: 0
#   Mutation: m685164, DP: 212, AD: 2
#   Mutation: m688860, DP: 275, AD: 0
#   Mutation: m695889, DP: 188, AD: 0
#   Mutation: m698130, DP: 185, AD: 1
#   Mutation: m700444, DP: 183, AD: 0
#   Mutation: m709966, DP: 268, AD: 1
#   Mutation: m712634, DP: 167, AD: 2
#   Mutation: m717142, DP: 218, AD: 0
#   Mutation: m723270, DP: 175, AD: 1
#   Mutation: m728288, DP: 160, AD: 0
#   Mutation: m728832, DP: 345, AD: 0
#   Mutation: m730054, DP: 286, AD: 0
#   Mutation: m742475, DP: 133, AD: 1
#   Mutation: m747322, DP: 199, AD: 0
#   Mutation: m74745, DP: 186, AD: 0
#   Mutation: m750735, DP: 178, AD: 0
#   Mutation: m7568, DP: 175, AD: 0
#   Mutation: m75784, DP: 169, AD: 0
#   Mutation: m767680, DP: 206, AD: 0
#   Mutation: m769339, DP: 200, AD: 0
#   Mutation: m770098, DP: 191, AD: 1
#   Mutation: m771085, DP: 176, AD: 0
#   Mutation: m772699, DP: 110, AD: 0
#   Mutation: m778701, DP: 205, AD: 1
#   Mutation: m779803, DP: 132, AD: 0
#   Mutation: m779912, DP: 183, AD: 0
#   Mutation: m786124, DP: 169, AD: 1
#   Mutation: m788183, DP: 241, AD: 0
#   Mutation: m78944, DP: 130, AD: 0
#   Mutation: m810924, DP: 165, AD: 2
#   Mutation: m813913, DP: 180, AD: 0
#   Mutation: m814980, DP: 215, AD: 0
#   Mutation: m815447, DP: 198, AD: 2
#   Mutation: m825357, DP: 243, AD: 0
#   Mutation: m827138, DP: 193, AD: 2
#   Mutation: m832985, DP: 206, AD: 0
#   Mutation: m838017, DP: 186, AD: 0
#   Mutation: m840837, DP: 177, AD: 0
#   Mutation: m843460, DP: 202, AD: 0
#   Mutation: m84613, DP: 245, AD: 1
#   Mutation: m851843, DP: 176, AD: 0
#   Mutation: m852139, DP: 211, AD: 0
#   Mutation: m8537, DP: 234, AD: 0
#   Mutation: m85687, DP: 251, AD: 0
#   Mutation: m861599, DP: 179, AD: 0
#   Mutation: m867683, DP: 162, AD: 0
#   Mutation: m868666, DP: 148, AD: 0
#   Mutation: m872139, DP: 248, AD: 2
#   Mutation: m87410, DP: 175, AD: 0
#   Mutation: m875092, DP: 207, AD: 1
#   Mutation: m879854, DP: 190, AD: 1
#   Mutation: m880020, DP: 179, AD: 0
#   Mutation: m880952, DP: 153, AD: 1
#   Mutation: m886378, DP: 192, AD: 0
#   Mutation: m889105, DP: 168, AD: 0
#   Mutation: m889393, DP: 147, AD: 0
#   Mutation: m889975, DP: 202, AD: 1
#   Mutation: m898568, DP: 174, AD: 1
#   Mutation: m904092, DP: 206, AD: 0
#   Mutation: m904438, DP: 191, AD: 0
#   Mutation: m910621, DP: 162, AD: 0
#   Mutation: m919820, DP: 216, AD: 1
#   Mutation: m920975, DP: 190, AD: 0
#   Mutation: m923320, DP: 165, AD: 0
#   Mutation: m932118, DP: 182, AD: 0
#   Mutation: m935209, DP: 137, AD: 0
#   Mutation: m940226, DP: 166, AD: 0
#   Mutation: m94535, DP: 217, AD: 1
#   Mutation: m949513, DP: 192, AD: 0
#   Mutation: m950956, DP: 220, AD: 0
#   Mutation: m954039, DP: 161, AD: 0
#   Mutation: m955333, DP: 132, AD: 1
#   Mutation: m956153, DP: 178, AD: 0
#   Mutation: m957718, DP: 129, AD: 0
#   Mutation: m960570, DP: 202, AD: 0
#   Mutation: m962596, DP: 235, AD: 1
#   Mutation: m962694, DP: 185, AD: 0
#   Mutation: m967158, DP: 262, AD: 0
#   Mutation: m971301, DP: 186, AD: 1
#   Mutation: m974362, DP: 155, AD: 0
#   Mutation: m977861, DP: 223, AD: 0
#   Mutation: m981343, DP: 252, AD: 0
#   Mutation: m988735, DP: 162, AD: 2
#   Mutation: m994025, DP: 173, AD: 0
#   Mutation: m998980, DP: 284, AD: 0
#   Mutation: m999770, DP: 162, AD: 0
#
# Cell ID: 1, Mutation Profile:
#   Mutation: m107714, DP: 199, AD: 0
#   Mutation: m111362, DP: 210, AD: 1
#   Mutation: m119528, DP: 202, AD: 1
#   Mutation: m122530, DP: 166, AD: 0
#   Mutation: m125730, DP: 185, AD: 0
#   Mutation: m131753, DP: 165, AD: 0
#   Mutation: m140854, DP: 227, AD: 1
#   Mutation: m148063, DP: 189, AD: 0
#   Mutation: m151590, DP: 129, AD: 0
#   Mutation: m151750, DP: 191, AD: 0
#   Mutation: m155210, DP: 288, AD: 1
#   Mutation: m157176, DP: 163, AD: 0
#   Mutation: m166002, DP: 164, AD: 0
#   Mutation: m182327, DP: 234, AD: 1
#   Mutation: m187442, DP: 211, AD: 0
#   Mutation: m190117, DP: 367, AD: 0
#   Mutation: m192567, DP: 202, AD: 0
#   Mutation: m193936, DP: 224, AD: 0
#   Mutation: m204221, DP: 261, AD: 1
#   Mutation: m210975, DP: 169, AD: 0
#   Mutation: m227026, DP: 262, AD: 0
#   Mutation: m229265, DP: 216, AD: 0
#   Mutation: m234180, DP: 161, AD: 1
#   Mutation: m240844, DP: 207, AD: 1
#   Mutation: m24470, DP: 143, AD: 0
#   Mutation: m255942, DP: 181, AD: 0
#   Mutation: m259942, DP: 192, AD: 0
#   Mutation: m262836, DP: 157, AD: 0
#   Mutation: m263024, DP: 174, AD: 0
#   Mutation: m264560, DP: 181, AD: 0
#   Mutation: m266651, DP: 192, AD: 0
#   Mutation: m270293, DP: 200, AD: 1
#   Mutation: m272781, DP: 216, AD: 0
#   Mutation: m278377, DP: 188, AD: 0
#   Mutation: m285015, DP: 173, AD: 0
#   Mutation: m293497, DP: 159, AD: 0
#   Mutation: m296525, DP: 148, AD: 1
#   Mutation: m297542, DP: 150, AD: 0
#   Mutation: m310363, DP: 195, AD: 0
#   Mutation: m311271, DP: 140, AD: 0
#   Mutation: m314168, DP: 165, AD: 0
#   Mutation: m314383, DP: 196, AD: 0
#   Mutation: m321108, DP: 194, AD: 0
#   Mutation: m324842, DP: 272, AD: 0
#   Mutation: m330298, DP: 290, AD: 0
#   Mutation: m330303, DP: 180, AD: 0
#   Mutation: m33484, DP: 170, AD: 0
#   Mutation: m357587, DP: 271, AD: 0
#   Mutation: m36089, DP: 261, AD: 1
#   Mutation: m368442, DP: 288, AD: 0
#   Mutation: m370516, DP: 170, AD: 0
#   Mutation: m371521, DP: 202, AD: 0
#   Mutation: m372922, DP: 176, AD: 0
#   Mutation: m375813, DP: 200, AD: 1
#   Mutation: m376277, DP: 224, AD: 0
#   Mutation: m382136, DP: 245, AD: 1
#   Mutation: m382846, DP: 198, AD: 0
#   Mutation: m38382, DP: 195, AD: 0
#   Mutation: m393490, DP: 232, AD: 0
#   Mutation: m397768, DP: 165, AD: 0
#   Mutation: m400399, DP: 218, AD: 1
#   Mutation: m400628, DP: 168, AD: 0
#   Mutation: m40080, DP: 190, AD: 2
#   Mutation: m401947, DP: 164, AD: 0
#   Mutation: m403748, DP: 232, AD: 0
#   Mutation: m414248, DP: 278, AD: 1
#   Mutation: m417852, DP: 183, AD: 1
#   Mutation: m42100, DP: 234, AD: 0
#   Mutation: m421605, DP: 228, AD: 0
#   Mutation: m431862, DP: 270, AD: 1
#   Mutation: m437780, DP: 219, AD: 1
#   Mutation: m44275, DP: 176, AD: 0
#   Mutation: m445580, DP: 162, AD: 0
#   Mutation: m448111, DP: 217, AD: 1
#   Mutation: m451050, DP: 162, AD: 0
#   Mutation: m464135, DP: 189, AD: 2
#   Mutation: m470364, DP: 185, AD: 1
#   Mutation: m473326, DP: 235, AD: 0
#   Mutation: m476362, DP: 198, AD: 0
#   Mutation: m482203, DP: 167, AD: 0
#   Mutation: m490762, DP: 178, AD: 1
#   Mutation: m491193, DP: 222, AD: 0
#   Mutation: m491319, DP: 177, AD: 0
#   Mutation: m497859, DP: 159, AD: 1
#   Mutation: m498567, DP: 244, AD: 1
#   Mutation: m499102, DP: 171, AD: 0
#   Mutation: m499313, DP: 172, AD: 0
#   Mutation: m504354, DP: 140, AD: 0
#   Mutation: m50612, DP: 195, AD: 0
#   Mutation: m513289, DP: 213, AD: 2
#   Mutation: m524726, DP: 239, AD: 0
#   Mutation: m530052, DP: 215, AD: 1
#   Mutation: m539466, DP: 172, AD: 0
#   Mutation: m544379, DP: 195, AD: 0
#   Mutation: m548364, DP: 177, AD: 1
#   Mutation: m551788, DP: 192, AD: 0
#   Mutation: m552565, DP: 258, AD: 0
#   Mutation: m572027, DP: 193, AD: 0
#   Mutation: m577486, DP: 173, AD: 1
#   Mutation: m580945, DP: 312, AD: 1
#   Mutation: m584610, DP: 187, AD: 0
#   Mutation: m58666, DP: 161, AD: 0
#   Mutation: m588509, DP: 226, AD: 0
#   Mutation: m600352, DP: 219, AD: 0
#   Mutation: m6024, DP: 171, AD: 0
#   Mutation: m602770, DP: 237, AD: 1
#   Mutation: m605824, DP: 267, AD: 1
#   Mutation: m606719, DP: 180, AD: 2
#   Mutation: m607110, DP: 227, AD: 0
#   Mutation: m614917, DP: 135, AD: 2
#   Mutation: m620821, DP: 187, AD: 0
#   Mutation: m625385, DP: 186, AD: 0
#   Mutation: m636906, DP: 159, AD: 0
#   Mutation: m637873, DP: 194, AD: 0
#   Mutation: m640880, DP: 167, AD: 0
#   Mutation: m640952, DP: 189, AD: 1
#   Mutation: m641950, DP: 163, AD: 0
#   Mutation: m644711, DP: 235, AD: 0
#   Mutation: m645379, DP: 189, AD: 4
#   Mutation: m653256, DP: 238, AD: 0
#   Mutation: m654132, DP: 180, AD: 0
#   Mutation: m654431, DP: 133, AD: 0
#   Mutation: m656195, DP: 191, AD: 1
#   Mutation: m658488, DP: 284, AD: 0
#   Mutation: m658903, DP: 196, AD: 1
#   Mutation: m67561, DP: 268, AD: 0
#   Mutation: m677831, DP: 189, AD: 2
#   Mutation: m67810, DP: 228, AD: 1
#   Mutation: m685094, DP: 237, AD: 0
#   Mutation: m685164, DP: 234, AD: 0
#   Mutation: m688860, DP: 170, AD: 1
#   Mutation: m695889, DP: 150, AD: 1
#   Mutation: m698130, DP: 209, AD: 0
#   Mutation: m700444, DP: 142, AD: 2
#   Mutation: m709966, DP: 233, AD: 0
#   Mutation: m712634, DP: 277, AD: 0
#   Mutation: m717142, DP: 244, AD: 0
#   Mutation: m723270, DP: 193, AD: 1
#   Mutation: m728288, DP: 249, AD: 0
#   Mutation: m728832, DP: 212, AD: 1
#   Mutation: m730054, DP: 195, AD: 0
#   Mutation: m742475, DP: 313, AD: 1
#   Mutation: m747322, DP: 207, AD: 1
#   Mutation: m74745, DP: 159, AD: 2
#   Mutation: m750735, DP: 278, AD: 0
#   Mutation: m7568, DP: 183, AD: 0
#   Mutation: m75784, DP: 294, AD: 0
#   Mutation: m767680, DP: 137, AD: 0
#   Mutation: m769339, DP: 235, AD: 0
#   Mutation: m770098, DP: 231, AD: 0
#   Mutation: m771085, DP: 187, AD: 1
#   Mutation: m772699, DP: 170, AD: 0
#   Mutation: m778701, DP: 251, AD: 0
#   Mutation: m779803, DP: 136, AD: 0
#   Mutation: m779912, DP: 206, AD: 0
#   Mutation: m786124, DP: 286, AD: 0
#   Mutation: m788183, DP: 192, AD: 1
#   Mutation: m78944, DP: 173, AD: 0
#   Mutation: m810924, DP: 206, AD: 0
#   Mutation: m813913, DP: 264, AD: 0
#   Mutation: m814980, DP: 200, AD: 0
#   Mutation: m815447, DP: 234, AD: 2
#   Mutation: m825357, DP: 204, AD: 0
#   Mutation: m827138, DP: 153, AD: 0
#   Mutation: m832985, DP: 204, AD: 0
#   Mutation: m838017, DP: 162, AD: 0
#   Mutation: m840837, DP: 196, AD: 0
#   Mutation: m843460, DP: 184, AD: 1
#   Mutation: m84613, DP: 175, AD: 0
#   Mutation: m851843, DP: 183, AD: 0
#   Mutation: m852139, DP: 233, AD: 0
#   Mutation: m8537, DP: 176, AD: 0
#   Mutation: m85687, DP: 206, AD: 0
#   Mutation: m861599, DP: 155, AD: 0
#   Mutation: m867683, DP: 196, AD: 0
#   Mutation: m868666, DP: 221, AD: 1
#   Mutation: m872139, DP: 200, AD: 0
#   Mutation: m87410, DP: 197, AD: 0
#   Mutation: m875092, DP: 216, AD: 1
#   Mutation: m879854, DP: 214, AD: 0
#   Mutation: m880020, DP: 197, AD: 0
#   Mutation: m880952, DP: 199, AD: 2
#   Mutation: m886378, DP: 250, AD: 1
#   Mutation: m889105, DP: 223, AD: 0
#   Mutation: m889393, DP: 171, AD: 2
#   Mutation: m889975, DP: 240, AD: 0
#   Mutation: m898568, DP: 243, AD: 1
#   Mutation: m904092, DP: 189, AD: 1
#   Mutation: m904438, DP: 191, AD: 0
#   Mutation: m910621, DP: 195, AD: 0
#   Mutation: m919820, DP: 146, AD: 0
#   Mutation: m920975, DP: 203, AD: 2
#   Mutation: m923320, DP: 179, AD: 0
#   Mutation: m932118, DP: 262, AD: 1
#   Mutation: m935209, DP: 221, AD: 0
#   Mutation: m940226, DP: 179, AD: 0
#   Mutation: m94535, DP: 255, AD: 1
#   Mutation: m949513, DP: 221, AD: 0
#   Mutation: m950956, DP: 222, AD: 0
#   Mutation: m954039, DP: 245, AD: 1
#   Mutation: m955333, DP: 218, AD: 0
#   Mutation: m956153, DP: 160, AD: 0
#   Mutation: m957718, DP: 201, AD: 1
#   Mutation: m960570, DP: 187, AD: 0
#   Mutation: m962596, DP: 259, AD: 0
#   Mutation: m962694, DP: 203, AD: 1
#   Mutation: m967158, DP: 156, AD: 0
#   Mutation: m971301, DP: 193, AD: 0
#   Mutation: m974362, DP: 145, AD: 1
#   Mutation: m977861, DP: 301, AD: 0
#   Mutation: m981343, DP: 208, AD: 1
#   Mutation: m988735, DP: 130, AD: 0
#   Mutation: m994025, DP: 251, AD: 0
#   Mutation: m998980, DP: 216, AD: 1
#   Mutation: m999770, DP: 259, AD: 0
#
# Cell ID: 2, Mutation Profile:
#   Mutation: m107714, DP: 227, AD: 1
#   Mutation: m111362, DP: 237, AD: 0
#   Mutation: m119528, DP: 261, AD: 1
#   Mutation: m122530, DP: 178, AD: 0
#   Mutation: m125730, DP: 199, AD: 1
#   Mutation: m131753, DP: 199, AD: 0
#   Mutation: m140854, DP: 195, AD: 1
#   Mutation: m148063, DP: 192, AD: 0
#   Mutation: m151590, DP: 188, AD: 0
#   Mutation: m151750, DP: 214, AD: 0
#   Mutation: m155210, DP: 267, AD: 2
#   Mutation: m157176, DP: 205, AD: 1
#   Mutation: m166002, DP: 165, AD: 0
#   Mutation: m182327, DP: 151, AD: 1
#   Mutation: m187442, DP: 168, AD: 1
#   Mutation: m190117, DP: 151, AD: 0
#   Mutation: m192567, DP: 193, AD: 0
#   Mutation: m193936, DP: 128, AD: 0
#   Mutation: m204221, DP: 220, AD: 1
#   Mutation: m210975, DP: 281, AD: 0
#   Mutation: m227026, DP: 262, AD: 1
#   Mutation: m229265, DP: 223, AD: 0
#   Mutation: m234180, DP: 185, AD: 1
#   Mutation: m240844, DP: 275, AD: 0
#   Mutation: m24470, DP: 173, AD: 1
#   Mutation: m255942, DP: 200, AD: 0
#   Mutation: m259942, DP: 233, AD: 1
#   Mutation: m262836, DP: 208, AD: 1
#   Mutation: m263024, DP: 218, AD: 0
#   Mutation: m264560, DP: 168, AD: 0
#   Mutation: m266651, DP: 180, AD: 0
#   Mutation: m270293, DP: 213, AD: 0
#   Mutation: m272781, DP: 223, AD: 0
#   Mutation: m278377, DP: 206, AD: 1
#   Mutation: m285015, DP: 162, AD: 0
#   Mutation: m293497, DP: 185, AD: 0
#   Mutation: m296525, DP: 186, AD: 1
#   Mutation: m297542, DP: 184, AD: 0
#   Mutation: m310363, DP: 127, AD: 1
#   Mutation: m311271, DP: 174, AD: 1
#   Mutation: m314168, DP: 153, AD: 0
#   Mutation: m314383, DP: 150, AD: 0
#   Mutation: m321108, DP: 248, AD: 0
#   Mutation: m324842, DP: 164, AD: 0
#   Mutation: m330298, DP: 155, AD: 0
#   Mutation: m330303, DP: 131, AD: 1
#   Mutation: m33484, DP: 267, AD: 0
#   Mutation: m357587, DP: 217, AD: 0
#   Mutation: m36089, DP: 190, AD: 0
#   Mutation: m368442, DP: 196, AD: 1
#   Mutation: m370516, DP: 152, AD: 0
#   Mutation: m371521, DP: 123, AD: 0
#   Mutation: m372922, DP: 187, AD: 1
#   Mutation: m375813, DP: 174, AD: 0
#   Mutation: m376277, DP: 197, AD: 0
#   Mutation: m382136, DP: 113, AD: 0
#   Mutation: m382846, DP: 151, AD: 1
#   Mutation: m38382, DP: 219, AD: 0
#   Mutation: m393490, DP: 217, AD: 1
#   Mutation: m397768, DP: 172, AD: 0
#   Mutation: m400399, DP: 191, AD: 0
#   Mutation: m400628, DP: 149, AD: 0
#   Mutation: m40080, DP: 154, AD: 0
#   Mutation: m401947, DP: 234, AD: 2
#   Mutation: m403748, DP: 224, AD: 1
#   Mutation: m414248, DP: 173, AD: 0
#   Mutation: m417852, DP: 216, AD: 1
#   Mutation: m42100, DP: 203, AD: 0
#   Mutation: m421605, DP: 173, AD: 0
#   Mutation: m431862, DP: 127, AD: 0
#   Mutation: m437780, DP: 201, AD: 0
#   Mutation: m44275, DP: 198, AD: 0
#   Mutation: m445580, DP: 127, AD: 0
#   Mutation: m448111, DP: 118, AD: 0
#   Mutation: m451050, DP: 202, AD: 0
#   Mutation: m464135, DP: 122, AD: 0
#   Mutation: m470364, DP: 164, AD: 1
#   Mutation: m473326, DP: 226, AD: 0
#   Mutation: m476362, DP: 137, AD: 0
#   Mutation: m482203, DP: 195, AD: 0
#   Mutation: m490762, DP: 224, AD: 0
#   Mutation: m491193, DP: 122, AD: 0
#   Mutation: m491319, DP: 221, AD: 1
#   Mutation: m497859, DP: 197, AD: 0
#   Mutation: m498567, DP: 170, AD: 1
#   Mutation: m499102, DP: 273, AD: 1
#   Mutation: m499313, DP: 182, AD: 0
#   Mutation: m504354, DP: 229, AD: 2
#   Mutation: m50612, DP: 199, AD: 1
#   Mutation: m513289, DP: 203, AD: 1
#   Mutation: m524726, DP: 277, AD: 1
#   Mutation: m530052, DP: 143, AD: 0
#   Mutation: m539466, DP: 225, AD: 0
#   Mutation: m544379, DP: 187, AD: 1
#   Mutation: m548364, DP: 311, AD: 0
#   Mutation: m551788, DP: 146, AD: 1
#   Mutation: m552565, DP: 173, AD: 1
#   Mutation: m572027, DP: 214, AD: 1
#   Mutation: m577486, DP: 239, AD: 0
#   Mutation: m580945, DP: 345, AD: 1
#   Mutation: m584610, DP: 332, AD: 0
#   Mutation: m58666, DP: 160, AD: 0
#   Mutation: m588509, DP: 225, AD: 0
#   Mutation: m600352, DP: 185, AD: 0
#   Mutation: m6024, DP: 242, AD: 1
#   Mutation: m602770, DP: 212, AD: 0
#   Mutation: m605824, DP: 215, AD: 1
#   Mutation: m606719, DP: 128, AD: 0
#   Mutation: m607110, DP: 225, AD: 1
#   Mutation: m614917, DP: 233, AD: 0
#   Mutation: m620821, DP: 325, AD: 0
#   Mutation: m625385, DP: 241, AD: 2
#   Mutation: m636906, DP: 171, AD: 0
#   Mutation: m637873, DP: 262, AD: 2
#   Mutation: m640880, DP: 163, AD: 1
#   Mutation: m640952, DP: 213, AD: 1
#   Mutation: m641950, DP: 278, AD: 0
#   Mutation: m644711, DP: 263, AD: 0
#   Mutation: m645379, DP: 258, AD: 1
#   Mutation: m653256, DP: 176, AD: 0
#   Mutation: m654132, DP: 236, AD: 1
#   Mutation: m654431, DP: 242, AD: 0
#   Mutation: m656195, DP: 246, AD: 0
#   Mutation: m658488, DP: 176, AD: 0
#   Mutation: m658903, DP: 158, AD: 1
#   Mutation: m67561, DP: 202, AD: 1
#   Mutation: m677831, DP: 187, AD: 0
#   Mutation: m67810, DP: 154, AD: 0
#   Mutation: m685094, DP: 202, AD: 0
#   Mutation: m685164, DP: 236, AD: 1
#   Mutation: m688860, DP: 218, AD: 1
#   Mutation: m695889, DP: 235, AD: 1
#   Mutation: m698130, DP: 222, AD: 1
#   Mutation: m700444, DP: 240, AD: 2
#   Mutation: m709966, DP: 226, AD: 0
#   Mutation: m712634, DP: 197, AD: 0
#   Mutation: m717142, DP: 170, AD: 1
#   Mutation: m723270, DP: 211, AD: 0
#   Mutation: m728288, DP: 194, AD: 0
#   Mutation: m728832, DP: 227, AD: 2
#   Mutation: m730054, DP: 188, AD: 0
#   Mutation: m742475, DP: 185, AD: 1
#   Mutation: m747322, DP: 192, AD: 0
#   Mutation: m74745, DP: 163, AD: 0
#   Mutation: m750735, DP: 209, AD: 0
#   Mutation: m7568, DP: 161, AD: 0
#   Mutation: m75784, DP: 245, AD: 0
#   Mutation: m767680, DP: 281, AD: 0
#   Mutation: m769339, DP: 154, AD: 0
#   Mutation: m770098, DP: 164, AD: 1
#   Mutation: m771085, DP: 145, AD: 0
#   Mutation: m772699, DP: 190, AD: 0
#   Mutation: m778701, DP: 142, AD: 0
#   Mutation: m779803, DP: 223, AD: 2
#   Mutation: m779912, DP: 332, AD: 0
#   Mutation: m786124, DP: 198, AD: 0
#   Mutation: m788183, DP: 150, AD: 1
#   Mutation: m78944, DP: 205, AD: 1
#   Mutation: m810924, DP: 134, AD: 0
#   Mutation: m813913, DP: 179, AD: 0
#   Mutation: m814980, DP: 183, AD: 1
#   Mutation: m815447, DP: 236, AD: 1
#   Mutation: m825357, DP: 270, AD: 1
#   Mutation: m827138, DP: 205, AD: 0
#   Mutation: m832985, DP: 212, AD: 0
#   Mutation: m838017, DP: 187, AD: 0
#   Mutation: m840837, DP: 258, AD: 0
#   Mutation: m843460, DP: 190, AD: 0
#   Mutation: m84613, DP: 268, AD: 0
#   Mutation: m851843, DP: 310, AD: 0
#   Mutation: m852139, DP: 167, AD: 1
#   Mutation: m8537, DP: 318, AD: 1
#   Mutation: m85687, DP: 155, AD: 0
#   Mutation: m861599, DP: 170, AD: 0
#   Mutation: m867683, DP: 145, AD: 0
#   Mutation: m868666, DP: 163, AD: 0
#   Mutation: m872139, DP: 236, AD: 0
#   Mutation: m87410, DP: 214, AD: 2
#   Mutation: m875092, DP: 216, AD: 0
#   Mutation: m879854, DP: 211, AD: 0
#   Mutation: m880020, DP: 122, AD: 1
#   Mutation: m880952, DP: 224, AD: 0
#   Mutation: m886378, DP: 202, AD: 3
#   Mutation: m889105, DP: 185, AD: 0
#   Mutation: m889393, DP: 154, AD: 0
#   Mutation: m889975, DP: 229, AD: 0
#   Mutation: m898568, DP: 158, AD: 1
#   Mutation: m904092, DP: 201, AD: 1
#   Mutation: m904438, DP: 136, AD: 0
#   Mutation: m910621, DP: 164, AD: 0
#   Mutation: m919820, DP: 258, AD: 3
#   Mutation: m920975, DP: 237, AD: 1
#   Mutation: m923320, DP: 213, AD: 1
#   Mutation: m932118, DP: 205, AD: 0
#   Mutation: m935209, DP: 200, AD: 0
#   Mutation: m940226, DP: 185, AD: 1
#   Mutation: m94535, DP: 222, AD: 1
#   Mutation: m949513, DP: 172, AD: 0
#   Mutation: m950956, DP: 213, AD: 0
#   Mutation: m954039, DP: 161, AD: 0
#   Mutation: m955333, DP: 259, AD: 1
#   Mutation: m956153, DP: 184, AD: 0
#   Mutation: m957718, DP: 163, AD: 0
#   Mutation: m960570, DP: 291, AD: 1
#   Mutation: m962596, DP: 310, AD: 2
#   Mutation: m962694, DP: 247, AD: 2
#   Mutation: m967158, DP: 210, AD: 0
#   Mutation: m971301, DP: 171, AD: 0
#   Mutation: m974362, DP: 235, AD: 0
#   Mutation: m977861, DP: 291, AD: 0
#   Mutation: m981343, DP: 150, AD: 0
#   Mutation: m988735, DP: 178, AD: 0
#   Mutation: m994025, DP: 143, AD: 1
#   Mutation: m998980, DP: 181, AD: 1
#   Mutation: m999770, DP: 167, AD: 0
#
# Cell ID: 3, Mutation Profile:
#   Mutation: m107714, DP: 155, AD: 0
#   Mutation: m111362, DP: 203, AD: 0
#   Mutation: m119528, DP: 301, AD: 0
#   Mutation: m122530, DP: 180, AD: 1
#   Mutation: m125730, DP: 143, AD: 0
#   Mutation: m131753, DP: 285, AD: 1
#   Mutation: m140854, DP: 132, AD: 1
#   Mutation: m148063, DP: 248, AD: 0
#   Mutation: m151590, DP: 215, AD: 1
#   Mutation: m151750, DP: 368, AD: 2
#   Mutation: m155210, DP: 153, AD: 2
#   Mutation: m157176, DP: 167, AD: 0
#   Mutation: m166002, DP: 156, AD: 0
#   Mutation: m182327, DP: 212, AD: 2
#   Mutation: m187442, DP: 179, AD: 0
#   Mutation: m190117, DP: 190, AD: 0
#   Mutation: m192567, DP: 243, AD: 0
#   Mutation: m193936, DP: 156, AD: 0
#   Mutation: m204221, DP: 223, AD: 0
#   Mutation: m210975, DP: 160, AD: 0
#   Mutation: m227026, DP: 158, AD: 0
#   Mutation: m229265, DP: 154, AD: 1
#   Mutation: m234180, DP: 162, AD: 1
#   Mutation: m240844, DP: 271, AD: 3
#   Mutation: m24470, DP: 172, AD: 0
#   Mutation: m255942, DP: 183, AD: 0
#   Mutation: m259942, DP: 216, AD: 0
#   Mutation: m262836, DP: 234, AD: 0
#   Mutation: m263024, DP: 227, AD: 0
#   Mutation: m264560, DP: 214, AD: 1
#   Mutation: m266651, DP: 166, AD: 1
#   Mutation: m270293, DP: 154, AD: 0
#   Mutation: m272781, DP: 240, AD: 0
#   Mutation: m278377, DP: 160, AD: 0
#   Mutation: m285015, DP: 318, AD: 2
#   Mutation: m293497, DP: 214, AD: 0
#   Mutation: m296525, DP: 184, AD: 0
#   Mutation: m297542, DP: 177, AD: 0
#   Mutation: m310363, DP: 196, AD: 0
#   Mutation: m311271, DP: 172, AD: 1
#   Mutation: m314168, DP: 216, AD: 0
#   Mutation: m314383, DP: 162, AD: 0
#   Mutation: m321108, DP: 170, AD: 0
#   Mutation: m324842, DP: 188, AD: 0
#   Mutation: m330298, DP: 153, AD: 0
#   Mutation: m330303, DP: 155, AD: 0
#   Mutation: m33484, DP: 215, AD: 0
#   Mutation: m357587, DP: 175, AD: 2
#   Mutation: m36089, DP: 175, AD: 0
#   Mutation: m368442, DP: 217, AD: 0
#   Mutation: m370516, DP: 158, AD: 0
#   Mutation: m371521, DP: 234, AD: 0
#   Mutation: m372922, DP: 155, AD: 0
#   Mutation: m375813, DP: 171, AD: 0
#   Mutation: m376277, DP: 143, AD: 1
#   Mutation: m382136, DP: 148, AD: 1
#   Mutation: m382846, DP: 154, AD: 1
#   Mutation: m38382, DP: 163, AD: 0
#   Mutation: m393490, DP: 200, AD: 0
#   Mutation: m397768, DP: 250, AD: 0
#   Mutation: m400399, DP: 174, AD: 0
#   Mutation: m400628, DP: 233, AD: 1
#   Mutation: m40080, DP: 189, AD: 0
#   Mutation: m401947, DP: 247, AD: 0
#   Mutation: m403748, DP: 144, AD: 0
#   Mutation: m414248, DP: 238, AD: 0
#   Mutation: m417852, DP: 136, AD: 0
#   Mutation: m42100, DP: 229, AD: 2
#   Mutation: m421605, DP: 200, AD: 0
#   Mutation: m431862, DP: 130, AD: 0
#   Mutation: m437780, DP: 190, AD: 0
#   Mutation: m44275, DP: 186, AD: 1
#   Mutation: m445580, DP: 215, AD: 0
#   Mutation: m448111, DP: 281, AD: 1
#   Mutation: m451050, DP: 183, AD: 0
#   Mutation: m464135, DP: 191, AD: 0
#   Mutation: m470364, DP: 169, AD: 0
#   Mutation: m473326, DP: 262, AD: 0
#   Mutation: m476362, DP: 216, AD: 0
#   Mutation: m482203, DP: 203, AD: 0
#   Mutation: m490762, DP: 208, AD: 0
#   Mutation: m491193, DP: 173, AD: 1
#   Mutation: m491319, DP: 146, AD: 0
#   Mutation: m497859, DP: 165, AD: 1
#   Mutation: m498567, DP: 155, AD: 0
#   Mutation: m499102, DP: 189, AD: 0
#   Mutation: m499313, DP: 204, AD: 0
#   Mutation: m504354, DP: 235, AD: 0
#   Mutation: m50612, DP: 223, AD: 0
#   Mutation: m513289, DP: 314, AD: 0
#   Mutation: m524726, DP: 114, AD: 1
#   Mutation: m530052, DP: 263, AD: 1
#   Mutation: m539466, DP: 210, AD: 0
#   Mutation: m544379, DP: 189, AD: 0
#   Mutation: m548364, DP: 292, AD: 1
#   Mutation: m551788, DP: 206, AD: 0
#   Mutation: m552565, DP: 172, AD: 1
#   Mutation: m572027, DP: 254, AD: 0
#   Mutation: m577486, DP: 189, AD: 0
#   Mutation: m580945, DP: 224, AD: 0
#   Mutation: m584610, DP: 171, AD: 1
#   Mutation: m58666, DP: 207, AD: 0
#   Mutation: m588509, DP: 201, AD: 0
#   Mutation: m600352, DP: 143, AD: 0
#   Mutation: m6024, DP: 140, AD: 0
#   Mutation: m602770, DP: 188, AD: 0
#   Mutation: m605824, DP: 215, AD: 0
#   Mutation: m606719, DP: 167, AD: 1
#   Mutation: m607110, DP: 130, AD: 0
#   Mutation: m614917, DP: 195, AD: 0
#   Mutation: m620821, DP: 195, AD: 0
#   Mutation: m625385, DP: 217, AD: 0
#   Mutation: m636906, DP: 148, AD: 0
#   Mutation: m637873, DP: 340, AD: 0
#   Mutation: m640880, DP: 174, AD: 2
#   Mutation: m640952, DP: 159, AD: 0
#   Mutation: m641950, DP: 194, AD: 0
#   Mutation: m644711, DP: 200, AD: 0
#   Mutation: m645379, DP: 162, AD: 0
#   Mutation: m653256, DP: 267, AD: 0
#   Mutation: m654132, DP: 170, AD: 1
#   Mutation: m654431, DP: 214, AD: 0
#   Mutation: m656195, DP: 161, AD: 2
#   Mutation: m658488, DP: 203, AD: 0
#   Mutation: m658903, DP: 237, AD: 0
#   Mutation: m67561, DP: 226, AD: 0
#   Mutation: m677831, DP: 135, AD: 1
#   Mutation: m67810, DP: 167, AD: 0
#   Mutation: m685094, DP: 202, AD: 0
#   Mutation: m685164, DP: 135, AD: 0
#   Mutation: m688860, DP: 221, AD: 0
#   Mutation: m695889, DP: 278, AD: 0
#   Mutation: m698130, DP: 154, AD: 0
#   Mutation: m700444, DP: 183, AD: 0
#   Mutation: m709966, DP: 142, AD: 0
#   Mutation: m712634, DP: 149, AD: 0
#   Mutation: m717142, DP: 170, AD: 0
#   Mutation: m723270, DP: 210, AD: 1
#   Mutation: m728288, DP: 242, AD: 1
#   Mutation: m728832, DP: 217, AD: 0
#   Mutation: m730054, DP: 141, AD: 1
#   Mutation: m742475, DP: 209, AD: 0
#   Mutation: m747322, DP: 142, AD: 0
#   Mutation: m74745, DP: 151, AD: 2
#   Mutation: m750735, DP: 179, AD: 0
#   Mutation: m7568, DP: 133, AD: 0
#   Mutation: m75784, DP: 140, AD: 0
#   Mutation: m767680, DP: 184, AD: 1
#   Mutation: m769339, DP: 181, AD: 0
#   Mutation: m770098, DP: 227, AD: 1
#   Mutation: m771085, DP: 154, AD: 1
#   Mutation: m772699, DP: 174, AD: 0
#   Mutation: m778701, DP: 183, AD: 0
#   Mutation: m779803, DP: 245, AD: 0
#   Mutation: m779912, DP: 214, AD: 2
#   Mutation: m786124, DP: 178, AD: 1
#   Mutation: m788183, DP: 153, AD: 0
#   Mutation: m78944, DP: 197, AD: 1
#   Mutation: m810924, DP: 178, AD: 0
#   Mutation: m813913, DP: 160, AD: 0
#   Mutation: m814980, DP: 258, AD: 0
#   Mutation: m815447, DP: 177, AD: 0
#   Mutation: m825357, DP: 219, AD: 1
#   Mutation: m827138, DP: 218, AD: 0
#   Mutation: m832985, DP: 205, AD: 1
#   Mutation: m838017, DP: 157, AD: 0
#   Mutation: m840837, DP: 132, AD: 0
#   Mutation: m843460, DP: 159, AD: 0
#   Mutation: m84613, DP: 184, AD: 0
#   Mutation: m851843, DP: 296, AD: 1
#   Mutation: m852139, DP: 193, AD: 2
#   Mutation: m8537, DP: 162, AD: 0
#   Mutation: m85687, DP: 216, AD: 0
#   Mutation: m861599, DP: 209, AD: 1
#   Mutation: m867683, DP: 198, AD: 0
#   Mutation: m868666, DP: 295, AD: 1
#   Mutation: m872139, DP: 204, AD: 1
#   Mutation: m87410, DP: 276, AD: 1
#   Mutation: m875092, DP: 178, AD: 0
#   Mutation: m879854, DP: 134, AD: 0
#   Mutation: m880020, DP: 160, AD: 0
#   Mutation: m880952, DP: 258, AD: 2
#   Mutation: m886378, DP: 237, AD: 0
#   Mutation: m889105, DP: 183, AD: 0
#   Mutation: m889393, DP: 185, AD: 0
#   Mutation: m889975, DP: 181, AD: 1
#   Mutation: m898568, DP: 320, AD: 0
#   Mutation: m904092, DP: 205, AD: 1
#   Mutation: m904438, DP: 193, AD: 0
#   Mutation: m910621, DP: 190, AD: 0
#   Mutation: m919820, DP: 237, AD: 0
#   Mutation: m920975, DP: 160, AD: 2
#   Mutation: m923320, DP: 133, AD: 0
#   Mutation: m932118, DP: 211, AD: 1
#   Mutation: m935209, DP: 190, AD: 0
#   Mutation: m940226, DP: 213, AD: 1
#   Mutation: m94535, DP: 241, AD: 0
#   Mutation: m949513, DP: 184, AD: 1
#   Mutation: m950956, DP: 221, AD: 0
#   Mutation: m954039, DP: 176, AD: 0
#   Mutation: m955333, DP: 184, AD: 2
#   Mutation: m956153, DP: 207, AD: 2
#   Mutation: m957718, DP: 232, AD: 0
#   Mutation: m960570, DP: 228, AD: 1
#   Mutation: m962596, DP: 144, AD: 0
#   Mutation: m962694, DP: 236, AD: 1
#   Mutation: m967158, DP: 250, AD: 0
#   Mutation: m971301, DP: 205, AD: 0
#   Mutation: m974362, DP: 187, AD: 0
#   Mutation: m977861, DP: 256, AD: 0
#   Mutation: m981343, DP: 196, AD: 3
#   Mutation: m988735, DP: 199, AD: 0
#   Mutation: m994025, DP: 232, AD: 1
#   Mutation: m998980, DP: 147, AD: 1
#   Mutation: m999770, DP: 149, AD: 0
#
# Cell ID: 4, Mutation Profile:
#   Mutation: m107714, DP: 192, AD: 0
#   Mutation: m111362, DP: 137, AD: 0
#   Mutation: m119528, DP: 198, AD: 1
#   Mutation: m122530, DP: 176, AD: 0
#   Mutation: m125730, DP: 196, AD: 1
#   Mutation: m131753, DP: 249, AD: 2
#   Mutation: m140854, DP: 185, AD: 0
#   Mutation: m148063, DP: 232, AD: 0
#   Mutation: m151590, DP: 222, AD: 0
#   Mutation: m151750, DP: 244, AD: 1
#   Mutation: m155210, DP: 242, AD: 1
#   Mutation: m157176, DP: 172, AD: 0
#   Mutation: m166002, DP: 150, AD: 1
#   Mutation: m182327, DP: 197, AD: 1
#   Mutation: m187442, DP: 165, AD: 1
#   Mutation: m190117, DP: 203, AD: 1
#   Mutation: m192567, DP: 237, AD: 0
#   Mutation: m193936, DP: 184, AD: 1
#   Mutation: m204221, DP: 194, AD: 0
#   Mutation: m210975, DP: 173, AD: 1
#   Mutation: m227026, DP: 185, AD: 0
#   Mutation: m229265, DP: 237, AD: 1
#   Mutation: m234180, DP: 210, AD: 0
#   Mutation: m240844, DP: 173, AD: 1
#   Mutation: m24470, DP: 149, AD: 1
#   Mutation: m255942, DP: 183, AD: 0
#   Mutation: m259942, DP: 157, AD: 0
#   Mutation: m262836, DP: 208, AD: 0
#   Mutation: m263024, DP: 153, AD: 1
#   Mutation: m264560, DP: 290, AD: 1
#   Mutation: m266651, DP: 244, AD: 0
#   Mutation: m270293, DP: 187, AD: 0
#   Mutation: m272781, DP: 147, AD: 0
#   Mutation: m278377, DP: 233, AD: 0
#   Mutation: m285015, DP: 202, AD: 0
#   Mutation: m293497, DP: 186, AD: 0
#   Mutation: m296525, DP: 297, AD: 0
#   Mutation: m297542, DP: 164, AD: 2
#   Mutation: m310363, DP: 173, AD: 0
#   Mutation: m311271, DP: 222, AD: 2
#   Mutation: m314168, DP: 148, AD: 2
#   Mutation: m314383, DP: 137, AD: 0
#   Mutation: m321108, DP: 139, AD: 0
#   Mutation: m324842, DP: 303, AD: 0
#   Mutation: m330298, DP: 161, AD: 0
#   Mutation: m330303, DP: 163, AD: 0
#   Mutation: m33484, DP: 286, AD: 1
#   Mutation: m357587, DP: 197, AD: 0
#   Mutation: m36089, DP: 153, AD: 1
#   Mutation: m368442, DP: 237, AD: 1
#   Mutation: m370516, DP: 117, AD: 1
#   Mutation: m371521, DP: 162, AD: 1
#   Mutation: m372922, DP: 186, AD: 0
#   Mutation: m375813, DP: 265, AD: 0
#   Mutation: m376277, DP: 217, AD: 0
#   Mutation: m382136, DP: 194, AD: 0
#   Mutation: m382846, DP: 223, AD: 1
#   Mutation: m38382, DP: 176, AD: 0
#   Mutation: m393490, DP: 183, AD: 0
#   Mutation: m397768, DP: 233, AD: 1
#   Mutation: m400399, DP: 145, AD: 1
#   Mutation: m400628, DP: 302, AD: 0
#   Mutation: m40080, DP: 163, AD: 1
#   Mutation: m401947, DP: 191, AD: 2
#   Mutation: m403748, DP: 212, AD: 0
#   Mutation: m414248, DP: 177, AD: 0
#   Mutation: m417852, DP: 146, AD: 0
#   Mutation: m42100, DP: 160, AD: 0
#   Mutation: m421605, DP: 174, AD: 1
#   Mutation: m431862, DP: 242, AD: 0
#   Mutation: m437780, DP: 196, AD: 0
#   Mutation: m44275, DP: 174, AD: 0
#   Mutation: m445580, DP: 180, AD: 0
#   Mutation: m448111, DP: 193, AD: 0
#   Mutation: m451050, DP: 179, AD: 0
#   Mutation: m464135, DP: 301, AD: 1
#   Mutation: m470364, DP: 173, AD: 0
#   Mutation: m473326, DP: 172, AD: 1
#   Mutation: m476362, DP: 256, AD: 0
#   Mutation: m482203, DP: 127, AD: 1
#   Mutation: m490762, DP: 196, AD: 0
#   Mutation: m491193, DP: 205, AD: 0
#   Mutation: m491319, DP: 176, AD: 0
#   Mutation: m497859, DP: 208, AD: 0
#   Mutation: m498567, DP: 251, AD: 1
#   Mutation: m499102, DP: 173, AD: 3
#   Mutation: m499313, DP: 297, AD: 1
#   Mutation: m504354, DP: 213, AD: 0
#   Mutation: m50612, DP: 192, AD: 1
#   Mutation: m513289, DP: 275, AD: 0
#   Mutation: m524726, DP: 238, AD: 0
#   Mutation: m530052, DP: 169, AD: 0
#   Mutation: m539466, DP: 189, AD: 0
#   Mutation: m544379, DP: 202, AD: 0
#   Mutation: m548364, DP: 138, AD: 0
#   Mutation: m551788, DP: 144, AD: 0
#   Mutation: m552565, DP: 272, AD: 1
#   Mutation: m572027, DP: 167, AD: 0
#   Mutation: m577486, DP: 183, AD: 0
#   Mutation: m580945, DP: 176, AD: 2
#   Mutation: m584610, DP: 235, AD: 0
#   Mutation: m58666, DP: 187, AD: 0
#   Mutation: m588509, DP: 288, AD: 0
#   Mutation: m600352, DP: 220, AD: 0
#   Mutation: m6024, DP: 122, AD: 0
#   Mutation: m602770, DP: 163, AD: 0
#   Mutation: m605824, DP: 150, AD: 1
#   Mutation: m606719, DP: 204, AD: 1
#   Mutation: m607110, DP: 149, AD: 0
#   Mutation: m614917, DP: 174, AD: 0
#   Mutation: m620821, DP: 335, AD: 0
#   Mutation: m625385, DP: 307, AD: 0
#   Mutation: m636906, DP: 163, AD: 0
#   Mutation: m637873, DP: 162, AD: 0
#   Mutation: m640880, DP: 178, AD: 1
#   Mutation: m640952, DP: 125, AD: 1
#   Mutation: m641950, DP: 149, AD: 0
#   Mutation: m644711, DP: 206, AD: 0
#   Mutation: m645379, DP: 172, AD: 0
#   Mutation: m653256, DP: 161, AD: 0
#   Mutation: m654132, DP: 223, AD: 1
#   Mutation: m654431, DP: 321, AD: 1
#   Mutation: m656195, DP: 168, AD: 0
#   Mutation: m658488, DP: 157, AD: 1
#   Mutation: m658903, DP: 178, AD: 1
#   Mutation: m67561, DP: 232, AD: 1
#   Mutation: m677831, DP: 195, AD: 1
#   Mutation: m67810, DP: 216, AD: 0
#   Mutation: m685094, DP: 201, AD: 0
#   Mutation: m685164, DP: 166, AD: 0
#   Mutation: m688860, DP: 154, AD: 0
#   Mutation: m695889, DP: 198, AD: 0
#   Mutation: m698130, DP: 129, AD: 0
#   Mutation: m700444, DP: 157, AD: 0
#   Mutation: m709966, DP: 149, AD: 0
#   Mutation: m712634, DP: 247, AD: 1
#   Mutation: m717142, DP: 175, AD: 2
#   Mutation: m723270, DP: 202, AD: 1
#   Mutation: m728288, DP: 238, AD: 0
#   Mutation: m728832, DP: 200, AD: 0
#   Mutation: m730054, DP: 142, AD: 1
#   Mutation: m742475, DP: 270, AD: 0
#   Mutation: m747322, DP: 144, AD: 0
#   Mutation: m74745, DP: 241, AD: 0
#   Mutation: m750735, DP: 128, AD: 0
#   Mutation: m7568, DP: 190, AD: 1
#   Mutation: m75784, DP: 228, AD: 0
#   Mutation: m767680, DP: 240, AD: 0
#   Mutation: m769339, DP: 222, AD: 0
#   Mutation: m770098, DP: 200, AD: 0
#   Mutation: m771085, DP: 185, AD: 0
#   Mutation: m772699, DP: 342, AD: 1
#   Mutation: m778701, DP: 225, AD: 1
#   Mutation: m779803, DP: 164, AD: 2
#   Mutation: m779912, DP: 217, AD: 0
#   Mutation: m786124, DP: 205, AD: 1
#   Mutation: m788183, DP: 208, AD: 0
#   Mutation: m78944, DP: 139, AD: 1
#   Mutation: m810924, DP: 189, AD: 0
#   Mutation: m813913, DP: 203, AD: 0
#   Mutation: m814980, DP: 136, AD: 0
#   Mutation: m815447, DP: 141, AD: 1
#   Mutation: m825357, DP: 179, AD: 1
#   Mutation: m827138, DP: 155, AD: 1
#   Mutation: m832985, DP: 130, AD: 0
#   Mutation: m838017, DP: 233, AD: 0
#   Mutation: m840837, DP: 190, AD: 0
#   Mutation: m843460, DP: 217, AD: 0
#   Mutation: m84613, DP: 222, AD: 0
#   Mutation: m851843, DP: 212, AD: 0
#   Mutation: m852139, DP: 162, AD: 0
#   Mutation: m8537, DP: 136, AD: 1
#   Mutation: m85687, DP: 203, AD: 0
#   Mutation: m861599, DP: 222, AD: 1
#   Mutation: m867683, DP: 188, AD: 0
#   Mutation: m868666, DP: 292, AD: 1
#   Mutation: m872139, DP: 156, AD: 0
#   Mutation: m87410, DP: 160, AD: 0
#   Mutation: m875092, DP: 211, AD: 2
#   Mutation: m879854, DP: 157, AD: 0
#   Mutation: m880020, DP: 175, AD: 0
#   Mutation: m880952, DP: 153, AD: 0
#   Mutation: m886378, DP: 165, AD: 0
#   Mutation: m889105, DP: 157, AD: 0
#   Mutation: m889393, DP: 192, AD: 0
#   Mutation: m889975, DP: 156, AD: 0
#   Mutation: m898568, DP: 315, AD: 0
#   Mutation: m904092, DP: 227, AD: 2
#   Mutation: m904438, DP: 218, AD: 1
#   Mutation: m910621, DP: 273, AD: 1
#   Mutation: m919820, DP: 184, AD: 1
#   Mutation: m920975, DP: 187, AD: 2
#   Mutation: m923320, DP: 228, AD: 0
#   Mutation: m932118, DP: 180, AD: 0
#   Mutation: m935209, DP: 196, AD: 0
#   Mutation: m940226, DP: 163, AD: 0
#   Mutation: m94535, DP: 173, AD: 0
#   Mutation: m949513, DP: 147, AD: 1
#   Mutation: m950956, DP: 134, AD: 1
#   Mutation: m954039, DP: 152, AD: 0
#   Mutation: m955333, DP: 215, AD: 0
#   Mutation: m956153, DP: 169, AD: 0
#   Mutation: m957718, DP: 240, AD: 0
#   Mutation: m960570, DP: 152, AD: 1
#   Mutation: m962596, DP: 167, AD: 0
#   Mutation: m962694, DP: 164, AD: 0
#   Mutation: m967158, DP: 182, AD: 0
#   Mutation: m971301, DP: 257, AD: 1
#   Mutation: m974362, DP: 196, AD: 0
#   Mutation: m977861, DP: 215, AD: 1
#   Mutation: m981343, DP: 231, AD: 0
#   Mutation: m988735, DP: 245, AD: 1
#   Mutation: m994025, DP: 208, AD: 0
#   Mutation: m998980, DP: 151, AD: 1
#   Mutation: m999770, DP: 193, AD: 0
#
# Simulated Gene Expression Data (first 5 cells):
#    Gene_0  Gene_1  Gene_2  Gene_3  Gene_4  Gene_5  Gene_6  Gene_7  Gene_8  \
# 0      18      46       8       4       5     146      64       9       4
# 1       0      55       2       3      51      52      40       1      48
# 2      18       0     176       2       2       0      23       5      28
# 3      16      62      17       4       0    1178      58       3     127
# 4       6      26       7       4       1     316      10      15      82
#
#    Gene_9  ...  Gene_3990  Gene_3991  Gene_3992  Gene_3993  Gene_3994  \
# 0       2  ...          0         36          0         23        371
# 1       3  ...         23         35          6         32         42
# 2       2  ...          3          1         30         76         41
# 3       6  ...         27         22         20          0        277
# 4       0  ...         21          8          0         16         39
#
#    Gene_3995  Gene_3996  Gene_3997  Gene_3998  Gene_3999
# 0         65         27         66          6         60
# 1         97          0        286         45        484
# 2         62         25         25          0        377
# 3          1          7         14         26        732
# 4         24         31         37         30          6
#
# [5 rows x 4000 columns]

# %%
all_cells[0].mutation_profile
# Out:
# {'m107714': {'DP': 229, 'AD': 0},
#  'm111362': {'DP': 255, 'AD': 1},
#  'm119528': {'DP': 159, 'AD': 1},
#  'm122530': {'DP': 198, 'AD': 0},
#  'm125730': {'DP': 246, 'AD': 0},
#  'm131753': {'DP': 202, 'AD': 0},
#  'm140854': {'DP': 249, 'AD': 0},
#  'm148063': {'DP': 158, 'AD': 0},
#  'm151590': {'DP': 178, 'AD': 0},
#  'm151750': {'DP': 170, 'AD': 1},
#  'm155210': {'DP': 213, 'AD': 1},
#  'm157176': {'DP': 285, 'AD': 2},
#  'm166002': {'DP': 201, 'AD': 0},
#  'm182327': {'DP': 154, 'AD': 0},
#  'm187442': {'DP': 196, 'AD': 1},
#  'm190117': {'DP': 211, 'AD': 0},
#  'm192567': {'DP': 209, 'AD': 0},
#  'm193936': {'DP': 122, 'AD': 0},
#  'm204221': {'DP': 156, 'AD': 1},
#  'm210975': {'DP': 133, 'AD': 1},
#  'm227026': {'DP': 169, 'AD': 1},
#  'm229265': {'DP': 280, 'AD': 1},
#  'm234180': {'DP': 154, 'AD': 2},
#  'm240844': {'DP': 174, 'AD': 0},
#  'm24470': {'DP': 142, 'AD': 0},
#  'm255942': {'DP': 230, 'AD': 1},
#  'm259942': {'DP': 155, 'AD': 1},
#  'm262836': {'DP': 194, 'AD': 2},
#  'm263024': {'DP': 283, 'AD': 0},
#  'm264560': {'DP': 190, 'AD': 0},
#  'm266651': {'DP': 321, 'AD': 1},
#  'm270293': {'DP': 145, 'AD': 1},
#  'm272781': {'DP': 181, 'AD': 0},
#  'm278377': {'DP': 214, 'AD': 1},
#  'm285015': {'DP': 202, 'AD': 0},
#  'm293497': {'DP': 259, 'AD': 0},
#  'm296525': {'DP': 230, 'AD': 0},
#  'm297542': {'DP': 267, 'AD': 2},
#  'm310363': {'DP': 229, 'AD': 0},
#  'm311271': {'DP': 158, 'AD': 0},
#  'm314168': {'DP': 199, 'AD': 1},
#  'm314383': {'DP': 183, 'AD': 1},
#  'm321108': {'DP': 178, 'AD': 1},
#  'm324842': {'DP': 176, 'AD': 0},
#  'm330298': {'DP': 211, 'AD': 2},
#  'm330303': {'DP': 189, 'AD': 0},
#  'm33484': {'DP': 248, 'AD': 1},
#  'm357587': {'DP': 163, 'AD': 0},
#  'm36089': {'DP': 137, 'AD': 0},
#  'm368442': {'DP': 144, 'AD': 0},
#  'm370516': {'DP': 281, 'AD': 0},
#  'm371521': {'DP': 243, 'AD': 0},
#  'm372922': {'DP': 167, 'AD': 0},
#  'm375813': {'DP': 141, 'AD': 0},
#  'm376277': {'DP': 152, 'AD': 0},
#  'm382136': {'DP': 189, 'AD': 1},
#  'm382846': {'DP': 215, 'AD': 0},
#  'm38382': {'DP': 307, 'AD': 3},
#  'm393490': {'DP': 198, 'AD': 0},
#  'm397768': {'DP': 226, 'AD': 0},
#  'm400399': {'DP': 245, 'AD': 0},
#  'm400628': {'DP': 158, 'AD': 1},
#  'm40080': {'DP': 230, 'AD': 0},
#  'm401947': {'DP': 178, 'AD': 0},
#  'm403748': {'DP': 113, 'AD': 0},
#  'm414248': {'DP': 161, 'AD': 0},
#  'm417852': {'DP': 186, 'AD': 0},
#  'm42100': {'DP': 164, 'AD': 0},
#  'm421605': {'DP': 144, 'AD': 0},
#  'm431862': {'DP': 163, 'AD': 0},
#  'm437780': {'DP': 220, 'AD': 0},
#  'm44275': {'DP': 171, 'AD': 1},
#  'm445580': {'DP': 235, 'AD': 0},
#  'm448111': {'DP': 172, 'AD': 1},
#  'm451050': {'DP': 243, 'AD': 0},
#  'm464135': {'DP': 211, 'AD': 2},
#  'm470364': {'DP': 216, 'AD': 1},
#  'm473326': {'DP': 191, 'AD': 0},
#  'm476362': {'DP': 157, 'AD': 0},
#  'm482203': {'DP': 165, 'AD': 0},
#  'm490762': {'DP': 307, 'AD': 0},
#  'm491193': {'DP': 245, 'AD': 0},
#  'm491319': {'DP': 172, 'AD': 0},
#  'm497859': {'DP': 302, 'AD': 0},
#  'm498567': {'DP': 198, 'AD': 1},
#  'm499102': {'DP': 163, 'AD': 0},
#  'm499313': {'DP': 241, 'AD': 0},
#  'm504354': {'DP': 232, 'AD': 1},
#  'm50612': {'DP': 217, 'AD': 0},
#  'm513289': {'DP': 172, 'AD': 0},
#  'm524726': {'DP': 160, 'AD': 0},
#  'm530052': {'DP': 312, 'AD': 3},
#  'm539466': {'DP': 183, 'AD': 2},
#  'm544379': {'DP': 199, 'AD': 0},
#  'm548364': {'DP': 236, 'AD': 0},
#  'm551788': {'DP': 197, 'AD': 0},
#  'm552565': {'DP': 213, 'AD': 2},
#  'm572027': {'DP': 152, 'AD': 1},
#  'm577486': {'DP': 158, 'AD': 0},
#  'm580945': {'DP': 280, 'AD': 1},
#  'm584610': {'DP': 146, 'AD': 0},
#  'm58666': {'DP': 161, 'AD': 1},
#  'm588509': {'DP': 178, 'AD': 0},
#  'm600352': {'DP': 224, 'AD': 0},
#  'm6024': {'DP': 175, 'AD': 0},
#  'm602770': {'DP': 148, 'AD': 0},
#  'm605824': {'DP': 149, 'AD': 1},
#  'm606719': {'DP': 268, 'AD': 1},
#  'm607110': {'DP': 187, 'AD': 0},
#  'm614917': {'DP': 135, 'AD': 1},
#  'm620821': {'DP': 197, 'AD': 0},
#  'm625385': {'DP': 239, 'AD': 1},
#  'm636906': {'DP': 161, 'AD': 0},
#  'm637873': {'DP': 200, 'AD': 1},
#  'm640880': {'DP': 270, 'AD': 0},
#  'm640952': {'DP': 204, 'AD': 2},
#  'm641950': {'DP': 217, 'AD': 0},
#  'm644711': {'DP': 235, 'AD': 0},
#  'm645379': {'DP': 214, 'AD': 0},
#  'm653256': {'DP': 187, 'AD': 2},
#  'm654132': {'DP': 313, 'AD': 1},
#  'm654431': {'DP': 222, 'AD': 0},
#  'm656195': {'DP': 279, 'AD': 0},
#  'm658488': {'DP': 204, 'AD': 0},
#  'm658903': {'DP': 136, 'AD': 0},
#  'm67561': {'DP': 134, 'AD': 0},
#  'm677831': {'DP': 143, 'AD': 0},
#  'm67810': {'DP': 168, 'AD': 1},
#  'm685094': {'DP': 246, 'AD': 0},
#  'm685164': {'DP': 212, 'AD': 2},
#  'm688860': {'DP': 275, 'AD': 0},
#  'm695889': {'DP': 188, 'AD': 0},
#  'm698130': {'DP': 185, 'AD': 1},
#  'm700444': {'DP': 183, 'AD': 0},
#  'm709966': {'DP': 268, 'AD': 1},
#  'm712634': {'DP': 167, 'AD': 2},
#  'm717142': {'DP': 218, 'AD': 0},
#  'm723270': {'DP': 175, 'AD': 1},
#  'm728288': {'DP': 160, 'AD': 0},
#  'm728832': {'DP': 345, 'AD': 0},
#  'm730054': {'DP': 286, 'AD': 0},
#  'm742475': {'DP': 133, 'AD': 1},
#  'm747322': {'DP': 199, 'AD': 0},
#  'm74745': {'DP': 186, 'AD': 0},
#  'm750735': {'DP': 178, 'AD': 0},
#  'm7568': {'DP': 175, 'AD': 0},
#  'm75784': {'DP': 169, 'AD': 0},
#  'm767680': {'DP': 206, 'AD': 0},
#  'm769339': {'DP': 200, 'AD': 0},
#  'm770098': {'DP': 191, 'AD': 1},
#  'm771085': {'DP': 176, 'AD': 0},
#  'm772699': {'DP': 110, 'AD': 0},
#  'm778701': {'DP': 205, 'AD': 1},
#  'm779803': {'DP': 132, 'AD': 0},
#  'm779912': {'DP': 183, 'AD': 0},
#  'm786124': {'DP': 169, 'AD': 1},
#  'm788183': {'DP': 241, 'AD': 0},
#  'm78944': {'DP': 130, 'AD': 0},
#  'm810924': {'DP': 165, 'AD': 2},
#  'm813913': {'DP': 180, 'AD': 0},
#  'm814980': {'DP': 215, 'AD': 0},
#  'm815447': {'DP': 198, 'AD': 2},
#  'm825357': {'DP': 243, 'AD': 0},
#  'm827138': {'DP': 193, 'AD': 2},
#  'm832985': {'DP': 206, 'AD': 0},
#  'm838017': {'DP': 186, 'AD': 0},
#  'm840837': {'DP': 177, 'AD': 0},
#  'm843460': {'DP': 202, 'AD': 0},
#  'm84613': {'DP': 245, 'AD': 1},
#  'm851843': {'DP': 176, 'AD': 0},
#  'm852139': {'DP': 211, 'AD': 0},
#  'm8537': {'DP': 234, 'AD': 0},
#  'm85687': {'DP': 251, 'AD': 0},
#  'm861599': {'DP': 179, 'AD': 0},
#  'm867683': {'DP': 162, 'AD': 0},
#  'm868666': {'DP': 148, 'AD': 0},
#  'm872139': {'DP': 248, 'AD': 2},
#  'm87410': {'DP': 175, 'AD': 0},
#  'm875092': {'DP': 207, 'AD': 1},
#  'm879854': {'DP': 190, 'AD': 1},
#  'm880020': {'DP': 179, 'AD': 0},
#  'm880952': {'DP': 153, 'AD': 1},
#  'm886378': {'DP': 192, 'AD': 0},
#  'm889105': {'DP': 168, 'AD': 0},
#  'm889393': {'DP': 147, 'AD': 0},
#  'm889975': {'DP': 202, 'AD': 1},
#  'm898568': {'DP': 174, 'AD': 1},
#  'm904092': {'DP': 206, 'AD': 0},
#  'm904438': {'DP': 191, 'AD': 0},
#  'm910621': {'DP': 162, 'AD': 0},
#  'm919820': {'DP': 216, 'AD': 1},
#  'm920975': {'DP': 190, 'AD': 0},
#  'm923320': {'DP': 165, 'AD': 0},
#  'm932118': {'DP': 182, 'AD': 0},
#  'm935209': {'DP': 137, 'AD': 0},
#  'm940226': {'DP': 166, 'AD': 0},
#  'm94535': {'DP': 217, 'AD': 1},
#  'm949513': {'DP': 192, 'AD': 0},
#  'm950956': {'DP': 220, 'AD': 0},
#  'm954039': {'DP': 161, 'AD': 0},
#  'm955333': {'DP': 132, 'AD': 1},
#  'm956153': {'DP': 178, 'AD': 0},
#  'm957718': {'DP': 129, 'AD': 0},
#  'm960570': {'DP': 202, 'AD': 0},
#  'm962596': {'DP': 235, 'AD': 1},
#  'm962694': {'DP': 185, 'AD': 0},
#  'm967158': {'DP': 262, 'AD': 0},
#  'm971301': {'DP': 186, 'AD': 1},
#  'm974362': {'DP': 155, 'AD': 0},
#  'm977861': {'DP': 223, 'AD': 0},
#  'm981343': {'DP': 252, 'AD': 0},
#  'm988735': {'DP': 162, 'AD': 2},
#  'm994025': {'DP': 173, 'AD': 0},
#  'm998980': {'DP': 284, 'AD': 0},
#  'm999770': {'DP': 162, 'AD': 0}}

# %% [markdown]
# ### **8. Code Explanation**
#
# - **Class Definitions**:
#   - `mtDNA` class represents individual mtDNA molecules, tracking their mutations.
#   - `Cell` class represents cells in the simulation, storing lineage information and cell type.
#
# - **mtDNA Dynamics Functions**:
#   - `introduce_mutations` introduces mutations into mtDNA molecules during replication.
#   - `replicate_and_segregate_mtDNA` handles mtDNA replication and random segregation into daughter cells.
#
# - **Cell Growth and Differentiation Functions**:
#   - `simulate_stem_cell_growth` models stem cell divisions using the Gillespie algorithm.
#   - `simulate_cell_differentiation` models differentiation of stem cells into progenitor cells and further into differentiated cells.
#   - `progenitor_asymmetric_division` simulates asymmetric division of progenitor cells.
#
# - **Gene Expression Simulation Functions**:
#   - `generate_gene_params` initializes gene-specific parameters for the simulation.
#   - `generate_latent_expression` computes the latent expression levels \( z_t \) for genes in a cell.
#   - `sample_expression` samples gene expression counts from a ZINB distribution.
#   - `simulate_gene_expression_for_cells` simulates gene expression data for all cells.
#
# - **Main Execution**:
#   - The simulation proceeds through stem cell growth, differentiation, parameter generation, and gene expression simulation.
#   - The final gene expression data is stored in `expression_df`.
#
# #### **Simulating Read Depth (DP and AD)**
#
# - **Function `simulate_read_depth`**:
#   - For each cell, we calculate the heteroplasmy levels of mutations.
#   - Total read depth (DP) for each mutation site is simulated using a Negative Binomial distribution to model overdispersion in sequencing coverage.
#   - Allele depth (AD) is simulated using a Binomial distribution based on the heteroplasmy level and the total read depth.
#   - Sequencing errors are included by adjusting the effective heteroplasmy with the base error rate.
#
# #### **Parameters Used**
#
# - **`mean_dp`**: The average total read depth per mutation site. This value can be adjusted to reflect different sequencing depths.
# - **`dp_dispersion`**: Controls the variance of the total read depth. A higher value indicates more overdispersion.
# - **`base_error_rate`**: The probability of a sequencing error at any given base. This affects the observed allele depth, particularly for low-frequency mutations.
#
# #### **Storing DP and AD**
#
# - Each cell's mitochondrial mutation profile is stored in the `mutation_profile` attribute, which is a dictionary mapping mutations to their DP and AD values.
#
# ---
#
# ### **9. Results and Interpretation**
#
# - **Gene Expression Data**:
#   - The simulated gene expression data (`expression_df`) contains realistic counts that mimic single-cell RNA-seq data.
#   - The data reflects cell-type-specific expression patterns due to the inclusion of cell-type-specific genes.
#
# - **Cell Type Distribution**:
#   - The simulation tracks the number of cells in each cell type, allowing for analysis of differentiation dynamics.
